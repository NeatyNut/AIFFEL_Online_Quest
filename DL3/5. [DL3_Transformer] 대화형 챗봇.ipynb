# %% [markdown]
# ## 프로젝트 목표

# %% [markdown]
# - 한국어 데이터로 챗봇 만들기

# %% [markdown]
# - 루브릭
#
# |평가문항|상세기준|
# |:---|:---|
# |1. 한국어 전처리를 통해 학습 데이터셋을 구축하였다.|공백과 특수문자 처리, 토크나이징, 병렬데이터 구축의 과정이 적절히 진행되었다.|
# |2. 트랜스포머 모델을 구현하여 한국어 챗봇 모델 학습을 정상적으로 진행하였다.|구현한 트랜스포머 모델이 한국어 병렬 데이터 학습 시 안정적으로 수렴하였다.|
# |3. 한국어 입력문장에 대해 한국어로 답변하는 함수를 구현하였다.|한국어 입력문장에 맥락에 맞는 한국어로 답변을 리턴하였다.|

# %% [markdown]
# ## 목차
# ---
# ### Step 1. 데이터 수집하기
# ### Step 2. 데이터 전처리하기
# ### Step 3. SubwordTextEncoder 사용하기
# ### Step 4. 모델 구성하기
# ### Step 5. 모델 평가하기

# %% [markdown]
# ## 프로젝트 진행
# ---

# %% [markdown]
# ### Step 1. 데이터 수집하기

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# - `Q, A 데이터쌍 불러오기`

# %%
df = pd.read_csv('https://raw.githubusercontent.com/songys/Chatbot_data/master/ChatbotData.csv')
df.head(5)
# Out:
#                  Q            A  label
# 0           12시 땡!   하루가 또 가네요.      0
# 1      1지망 학교 떨어졌어    위로해 드립니다.      0
# 2     3박4일 놀러가고 싶다  여행은 언제나 좋죠.      0
# 3  3박4일 정도 놀러가고 싶다  여행은 언제나 좋죠.      0
# 4          PPL 심하네   눈살이 찌푸려지죠.      0

# %% [markdown]
# - `데이터 구성 확인`

# %%
print("데이터별 개수")
print(df.count())
print()
print("결측치 확인")
print(df.isnull().sum())
print()
print(f"라벨의 종류 : {df['label'].unique()}")
sns.countplot(x=df['label'], data=df)
# Out:
# 데이터별 개수
# Q        11823
# A        11823
# label    11823
# dtype: int64
#
# 결측치 확인
# Q        0
# A        0
# label    0
# dtype: int64
#
# 라벨의 종류 : [0 1 2]
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# - `결측치가 없고` `라벨이 총 3가지`가 있으며, `데이터 분포가 불균형`한 것을 알 수 있었다.
# - 상대적으로 데이터의 수가 적고, 자연어 분야의 데이터 증강기법은 아직 모르기에 추 후 챗봇의 성능 개선 시 참고하고자 관련 논문을 링크해두었다.
#
# - 참고링크 : https://www.sciencedirect.com/science/article/abs/pii/S0969698922000303
#     - 논문 제목 : (Im)Balanced customer-oriented behaviors and AI chatbots' Efficiency–Flexibility performance: The moderating role of customers’ rational choices
#     - `불균형에 대한 부정적인 견해` : (Abstract 5번째 줄) Chatbots' level of efficiency–flexibility ambidexterity is higher when their functional and relational customer-oriented behaviors are balanced rather than imbalanced (i.e., a negative imbalance effect) and when they are balanced at a higher rather than a lower level (i.e., a positive balance effect).
#     - `결론적으로 균형된 데이터를 학습해야 유용하고 유연성있는 모델이 완성`된다.
# ---
#     - 단 시간관계상 이 부분은 성능개선에서 생각해보고자 한다.

# %% [markdown]
# - `라벨별 데이터 확인`
#     - 일상다반사 0
#     - 이별(부정) 1
#     - 사랑(긍정) 2

# %%
df[df['label'] == 0].head()
# Out:
#                  Q            A  label
# 0           12시 땡!   하루가 또 가네요.      0
# 1      1지망 학교 떨어졌어    위로해 드립니다.      0
# 2     3박4일 놀러가고 싶다  여행은 언제나 좋죠.      0
# 3  3박4일 정도 놀러가고 싶다  여행은 언제나 좋죠.      0
# 4          PPL 심하네   눈살이 찌푸려지죠.      0

# %%
df[df['label'] == 1].head()
# Out:
#                          Q                          A  label
# 5290     1000일 만난 여자친구와 이별         더 오래 만날 사람 만날 거예요.      1
# 5291       10년 연애. 헤어졌습니다.              더 공허함이 크시겠네요.      1
# 5292  10년 연애사 되돌아보니 다 부질없네           더 좋은 사람 만나실 거예요.      1
# 5293              10년 연예의끝               더 마음이 허하겠어요.      1
# 5294           10년만나다 헤어지네  충분히 슬퍼하고 충분히 아파하다가 이겨내세요.      1

# %%
df[df['label'] == 2].head()
# Out:
#                              Q                         A  label
# 8860        짝사랑만큼 고통스러운 건 없겠지.  짝사랑 만큼 감정소모가 큰 건 없을 거예요.      2
# 8861       1년 넘게 만났는데 지금도 불타올라         정열적인 사랑을 하고 있나봐요.      2
# 8862           1년 동거 중인데 계속 좋아    서로 깊게 알게되면서 더 좋아졌나봅니다.      2
# 8863              1년 동거하고 결혼했어                    축하합니다!      2
# 8864  1년 만났는데도 그 사람에 대해 잘 모르겠어                  더 만나보세요.      2

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from wordcloud import WordCloud

# 사용 가능한 폰트 리스트 출력
available_fonts = [font for font in fm.fontManager.ttflist if 'Nanum' in font.name or 'nanum' in font.name]

if available_fonts:
    chosen_font = available_fonts[0].fname # 첫 번째 폰트의 파일명을 선택
    print("선택된 폰트:", chosen_font)

    # 워드 클라우드 생성 시 선택된 폰트를 지정
    wordcloud = WordCloud(font_path=chosen_font, width=800, height=400, background_color='white').generate(' '.join(df['A']))
    plt.figure(figsize=(15, 7))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
else:
    print("Nanum 폰트가 사용 가능한 폰트 리스트에 없습니다.")
# Out:
# 선택된 폰트: /usr/share/fonts/truetype/nanum/NanumGothicBold.ttf

# %% [markdown]
# ### Step 2. 데이터 전처리하기

# %% [markdown]
# - `ㅋ,ㅎ,ㅜ,ㅠ 데이터 처리 고민`

# %%
const = df['Q'].str.contains('[ㄱ-ㅎㅏ-ㅣ]') |\
df['A'].str.contains('[ㄱ-ㅎㅏ-ㅣ]')

# %%
df[const]
# Out:
#                         Q                    A  label
# 7          SNS 맞팔 왜 안하지ㅠㅠ     잘 모르고 있을 수도 있어요.      0
# 211          공무원 시험 힘들어ㅠㅠ     철밥통 되기가 어디 쉽겠어요.      0
# 1153      단둘이는 처음 만나는 날ㅋㅋ  서로를 아는 좋은 기회가 되겠네요.      0
# 2104         보일러 틀고 나갔어ㅠㅠ   이번달 난방비가 많이 나오겠네요.      0
# 2229              비트코인 ㅜㅜ        안타깝지만 잊어버리세요.      0
# ...                   ...                  ...    ...
# 8778   황당하지만 재미난 일이 생겼네ㅎㅎ       무슨 일인지 말씀해주세요.      1
# 8787                 후.ㅎㅎ               지쳤나봐요.      1
# 8815                  휴우.                 휴우ㅠㅠ      1
# 8819        흐잌~~ 불금이닷~~ㅠㅠ                  퐈이야      1
# 10773            예쁘면 다냐ㅠㅠ         마음 아프게 했나봐요.      2
#
# [78 rows x 3 columns]

# %% [markdown]
# - 관련한 데이터 77개 확인
# - 데이터량이 작지만, ㅜㅠㅋㅎ은 한국어 표현에서 중요한 감정표현 정보이기에 `한 단어씩은 남기기`로 결정

# %% [markdown]
# - `영어 데이터 처리 고민`

# %%
const2 = df['Q'].str.contains('[a-zA-Z]') |\
df['A'].str.contains('[a-zA-Z]')

# %%
df[const2]
# Out:
#                                             Q                              A  \
# 4                                     PPL 심하네                     눈살이 찌푸려지죠.
# 5                                   SD카드 망가졌어             다시 새로 사는 게 마음 편해요.
# 6                                     SD카드 안돼             다시 새로 사는 게 마음 편해요.
# 7                              SNS 맞팔 왜 안하지ㅠㅠ               잘 모르고 있을 수도 있어요.
# 8                     SNS 시간낭비인 거 아는데 매일 하는 중                  시간을 정하고 해보세요.
# 9                           SNS 시간낭비인데 자꾸 보게됨                  시간을 정하고 해보세요.
# 10                        SNS보면 나만 빼고 다 행복해보여                    자랑하는 자리니까요.
# 754                           남친 SNS에 내 사진 없어                      신경쓰지 마세요.
# 762                       남친이 SNS에 내 사진에 안 올려                      신경쓰지 마세요.
# 1401                         떨어뜨려서 핸드폰 액정 나갔어                       as 맡기세요.
# 2432                               서핑하러 가고 싶다                      주말에 gogo.
# 2994                                   액정 나갔어                       as 맡기세요.
# 4742                                 컴터 고장났나봐                   AS센터에 맡겨보세요.
# 4744                                컴터가 맛이 갔어                   AS센터에 맡겨보세요.
# 4745                                   컴터가 안돼                   AS센터에 맡겨보세요.
# 5063                         핸드폰 떨어뜨려서 고장 났나봐                       as 맡기세요.
# 5420                            jk김동욱 노래 생각나네                    가사가 비슷한가봐요.
# 5421                           SNS 를 끊어야 하는데.                   SNS 끊는게 힘들죠.
# 5422                                   SNS 흔적                  SNS 흔적 삭제하세요.
# 5423              sns에서 다른 이성이랑 대화하는걸 보니 화가 나                    SNS 보지 마세요.
# 5639                           그녀에 sns를 봤습니다.             SNS는 보지 않는 게 좋겠어요.
# 5807                               나한테 욕 좀 해줘                          XX놈아!
# 6333                     몰래 sns 훔쳐보고 있는 나 한심해                  SNS 검색하지 마세요.
# 7127                     오늘 또 헤어진 사람의 sns를 봤네  sns를 삭제하는게 어떨까요. 미련만 남을 뿐이에요.
# 7164                        오늘도 전 여친sns를 봤습니다  sns를 삭제하는게 어떨까요. 미련만 남을 뿐이에요.
# 8359                                컴터가 맛이 갔어                   AS센터에 맡겨보세요.
# 8476                         핸드폰 떨어뜨려서 고장 났나봐                       as 맡기세요.
# 8572                           헤어진 남친의 SNS 행적                      SNS 끊으세요.
# 8887                             AB형 남자랑 썸 타면                    최대한 이해해보세요.
# 8888                             AB형 여자랑 썸 타면         하고 싶은 걸 표현할 수 있게 해주세요.
# 8889                           A형 남자랑 썸을 타게 됨                  사소한 걸 기억해보세요.
# 8890                           A형 여자랑 썸을 타게 됨                    세심하게 챙겨주세요.
# 8891                              B형 남자랑 썸 탐.                     계속 칭찬해보세요.
# 8892                              B형 여자랑 썸 탐.        자신이 가장 자신다울 수 있게 도와주세요.
# 8893                               CC 레알 별로임?        헤어질 경우 엮여 있는 사람이 많으니까요.
# 8894                            O형 남자와 썸을 타는데                      애교 부려보세요.
# 8895                            O형 여자와 썸을 타는데                     엄청 사랑해주세요.
# 8916          같은 과에 내 이상형인 남자애가 있는데 cc는 무리일까?           CC는 아무래도 제약이 있을 거예요.
# 9296                       남자친구가 sns에 나 안 올려.               개인 성향 차이인 것 같아요.
# 10572              여자친구가 나를 sns에 올리지 않아서 서운해.     SNS에 올리는 걸 안 좋아하는 사람도 있어요.
# 10661                      여자친구의 sns말투가 고민이야.                     아예 보지 마세요.
# 11083  좋아하는 사람 생기면 어떻게든 sns같은 거 알아내서 친신하고 그래?              다가가는 방법 중에 하나니까요.
#
#        label
# 4          0
# 5          0
# 6          0
# 7          0
# 8          0
# 9          0
# 10         0
# 754        0
# 762        0
# 1401       0
# 2432       0
# 2994       0
# 4742       0
# 4744       0
# 4745       0
# 5063       0
# 5420       1
# 5421       1
# 5422       1
# 5423       1
# 5639       1
# 5807       1
# 6333       1
# 7127       1
# 7164       1
# 8359       1
# 8476       1
# 8572       1
# 8887       2
# 8888       2
# 8889       2
# 8890       2
# 8891       2
# 8892       2
# 8893       2
# 8894       2
# 8895       2
# 8916       2
# 9296       2
# 10572      2
# 10661      2
# 11083      2

# %%
df[const2].count()
# Out:
# Q        42
# A        42
# label    42
# dtype: int64

# %% [markdown]
# - 관련한 데이터 42개 확인
# - sns, SNS, as, AS 등 통일 작업 필요`(Upper 사용 결정)`
# - 중요한 정보기에 남기기로 결정

# %% [markdown]
# - `숫자 데이터 처리 고민`

# %%
const3 = df['Q'].str.contains('[0-9]') |\
df['A'].str.contains('[0-9]')

# %%
df[const3]
# Out:
#                                   Q                             A  label
# 0                            12시 땡!                    하루가 또 가네요.      0
# 1                       1지망 학교 떨어졌어                     위로해 드립니다.      0
# 2                      3박4일 놀러가고 싶다                   여행은 언제나 좋죠.      0
# 3                   3박4일 정도 놀러가고 싶다                   여행은 언제나 좋죠.      0
# 67                  강렬한 첫인상 남겨야 하는데  처음 3초가 중요해요. 당신의 매력을 어필해보세요.      0
# ...                             ...                           ...    ...
# 10948  자기를 3인칭으로 말하는 여자친구의 말투가 고민임.                     귀엽게 봐주세요.      2
# 11184     좋아하는 애가 1년만 기다려 달라는데 어쩌지.        기다릴 수 있다면 본인 의지대로 하셔요.      2
# 11257       좋아하는데 걸린 시간이 보통 어떻게 돼요?   1초가 걸릴 수도 있고 평생이 걸릴 수도 있어요.      2
# 11390           짝남이 내가 좋아하는걸 1도 몰라.                    1은 알게 해야죠.      2
# 11522           짝녀가 좋아하는거 눈치 1도 못챔.                    1은 알게 해야죠.      2
#
# [415 rows x 3 columns]

# %% [markdown]
# - 415개 데이터 확인
# - 1지망, 1년, 3인칭 중요한 데이터가 두루 있는 것으로 판단되어 `살리는 것으로 결정`

# %% [markdown]
# - `전처리 함수 정의`

# %%
# 전처리 함수
def preprocess_sentence(sentence):
    # 입력받은 sentence를 소문자로 변경하고 양쪽 공백을 제거
    sentence = sentence.lower().strip()

    # 단어와 구두점(punctuation), (ㅋ,ㅎ,ㅜ,ㅠ) 사이의 거리를 만듭니다.
    # student와 온점 사이에 거리를 만듭니다.
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = re.sub(r'[" "]+', " ", sentence)
    # 영어 소문자 -> 대문자 변환 결정
    sentence = re.sub(r'[a-z]', lambda x: x.group(0).upper(), sentence)
    # 한글 초성, 중성 하나씩으로 변경, 띄어쓰기
    sentence = re.sub(r"([ㄱ-ㅎㅏ-ㅣ])\1+", r"\1", sentence)
    sentence = re.sub(r"([ㄱ-ㅎㅏ-ㅣ])", r" \1 ", sentence)
    
    # (a-z, A-Z, ".", "?", "!", ",")를 제외한 모든 문자를 공백인 ' '로 대체합니다
    # 가-힣ㄱ-ㅎㅏ-ㅣ0-9 추가하여 결정
    sentence = re.sub(r"[^a-zA-Z가-힣ㄱ-ㅎㅏ-ㅣ0-9?.!,]+", " ", sentence)
    sentence = sentence.strip()
    return sentence

# %%
df['Q'] = df['Q'].apply(lambda x:preprocess_sentence(x))
df['A'] = df['A'].apply(lambda x:preprocess_sentence(x))

# %%
df[const]
# Out:
#                         Q                     A  label
# 7          SNS 맞팔 왜 안하지 ㅠ     잘 모르고 있을 수도 있어요 .      0
# 211          공무원 시험 힘들어 ㅠ     철밥통 되기가 어디 쉽겠어요 .      0
# 1153      단둘이는 처음 만나는 날 ㅋ  서로를 아는 좋은 기회가 되겠네요 .      0
# 2104         보일러 틀고 나갔어 ㅠ   이번달 난방비가 많이 나오겠네요 .      0
# 2229               비트코인 ㅜ        안타깝지만 잊어버리세요 .      0
# ...                   ...                   ...    ...
# 8778   황당하지만 재미난 일이 생겼네 ㅎ       무슨 일인지 말씀해주세요 .      1
# 8787                후 . ㅎ               지쳤나봐요 .      1
# 8815                 휴우 .                  휴우 ㅠ      1
# 8819            흐잌 불금이닷 ㅠ                   퐈이야      1
# 10773            예쁘면 다냐 ㅠ         마음 아프게 했나봐요 .      2
#
# [78 rows x 3 columns]

# %%
df[const2]
# Out:
#                                              Q  \
# 4                                      PPL 심하네
# 5                                    SD카드 망가졌어
# 6                                      SD카드 안돼
# 7                               SNS 맞팔 왜 안하지 ㅠ
# 8                      SNS 시간낭비인 거 아는데 매일 하는 중
# 9                            SNS 시간낭비인데 자꾸 보게됨
# 10                         SNS보면 나만 빼고 다 행복해보여
# 754                            남친 SNS에 내 사진 없어
# 762                        남친이 SNS에 내 사진에 안 올려
# 1401                          떨어뜨려서 핸드폰 액정 나갔어
# 2432                                서핑하러 가고 싶다
# 2994                                    액정 나갔어
# 4742                                  컴터 고장났나봐
# 4744                                 컴터가 맛이 갔어
# 4745                                    컴터가 안돼
# 5063                          핸드폰 떨어뜨려서 고장 났나봐
# 5420                             JK김동욱 노래 생각나네
# 5421                           SNS 를 끊어야 하는데 .
# 5422                                    SNS 흔적
# 5423               SNS에서 다른 이성이랑 대화하는걸 보니 화가 나
# 5639                           그녀에 SNS를 봤습니다 .
# 5807                                나한테 욕 좀 해줘
# 6333                      몰래 SNS 훔쳐보고 있는 나 한심해
# 7127                      오늘 또 헤어진 사람의 SNS를 봤네
# 7164                         오늘도 전 여친SNS를 봤습니다
# 8359                                 컴터가 맛이 갔어
# 8476                          핸드폰 떨어뜨려서 고장 났나봐
# 8572                            헤어진 남친의 SNS 행적
# 8887                              AB형 남자랑 썸 타면
# 8888                              AB형 여자랑 썸 타면
# 8889                            A형 남자랑 썸을 타게 됨
# 8890                            A형 여자랑 썸을 타게 됨
# 8891                              B형 남자랑 썸 탐 .
# 8892                              B형 여자랑 썸 탐 .
# 8893                               CC 레알 별로임 ?
# 8894                             O형 남자와 썸을 타는데
# 8895                             O형 여자와 썸을 타는데
# 8916          같은 과에 내 이상형인 남자애가 있는데 CC는 무리일까 ?
# 9296                       남자친구가 SNS에 나 안 올려 .
# 10572              여자친구가 나를 SNS에 올리지 않아서 서운해 .
# 10661                      여자친구의 SNS말투가 고민이야 .
# 11083  좋아하는 사람 생기면 어떻게든 SNS같은 거 알아내서 친신하고 그래 ?
#
#                                      A  label
# 4                          눈살이 찌푸려지죠 .      0
# 5                  다시 새로 사는 게 마음 편해요 .      0
# 6                  다시 새로 사는 게 마음 편해요 .      0
# 7                    잘 모르고 있을 수도 있어요 .      0
# 8                       시간을 정하고 해보세요 .      0
# 9                       시간을 정하고 해보세요 .      0
# 10                        자랑하는 자리니까요 .      0
# 754                         신경쓰지 마세요 .      0
# 762                         신경쓰지 마세요 .      0
# 1401                         AS 맡기세요 .      0
# 2432                        주말에 GOGO .      0
# 2994                         AS 맡기세요 .      0
# 4742                     AS센터에 맡겨보세요 .      0
# 4744                     AS센터에 맡겨보세요 .      0
# 4745                     AS센터에 맡겨보세요 .      0
# 5063                         AS 맡기세요 .      0
# 5420                      가사가 비슷한가봐요 .      1
# 5421                     SNS 끊는게 힘들죠 .      1
# 5422                    SNS 흔적 삭제하세요 .      1
# 5423                      SNS 보지 마세요 .      1
# 5639               SNS는 보지 않는 게 좋겠어요 .      1
# 5807                            XX놈아 !      1
# 6333                    SNS 검색하지 마세요 .      1
# 7127   SNS를 삭제하는게 어떨까요 . 미련만 남을 뿐이에요 .      1
# 7164   SNS를 삭제하는게 어떨까요 . 미련만 남을 뿐이에요 .      1
# 8359                     AS센터에 맡겨보세요 .      1
# 8476                         AS 맡기세요 .      1
# 8572                        SNS 끊으세요 .      1
# 8887                      최대한 이해해보세요 .      2
# 8888           하고 싶은 걸 표현할 수 있게 해주세요 .      2
# 8889                    사소한 걸 기억해보세요 .      2
# 8890                      세심하게 챙겨주세요 .      2
# 8891                       계속 칭찬해보세요 .      2
# 8892          자신이 가장 자신다울 수 있게 도와주세요 .      2
# 8893          헤어질 경우 엮여 있는 사람이 많으니까요 .      2
# 8894                        애교 부려보세요 .      2
# 8895                       엄청 사랑해주세요 .      2
# 8916             CC는 아무래도 제약이 있을 거예요 .      2
# 9296                 개인 성향 차이인 것 같아요 .      2
# 10572      SNS에 올리는 걸 안 좋아하는 사람도 있어요 .      2
# 10661                      아예 보지 마세요 .      2
# 11083               다가가는 방법 중에 하나니까요 .      2

# %%
df[const3]
# Out:
#                                    Q                               A  label
# 0                            12시 땡 !                     하루가 또 가네요 .      0
# 1                        1지망 학교 떨어졌어                      위로해 드립니다 .      0
# 2                       3박4일 놀러가고 싶다                    여행은 언제나 좋죠 .      0
# 3                    3박4일 정도 놀러가고 싶다                    여행은 언제나 좋죠 .      0
# 67                   강렬한 첫인상 남겨야 하는데  처음 3초가 중요해요 . 당신의 매력을 어필해보세요 .      0
# ...                              ...                             ...    ...
# 10948  자기를 3인칭으로 말하는 여자친구의 말투가 고민임 .                      귀엽게 봐주세요 .      2
# 11184     좋아하는 애가 1년만 기다려 달라는데 어쩌지 .         기다릴 수 있다면 본인 의지대로 하셔요 .      2
# 11257       좋아하는데 걸린 시간이 보통 어떻게 돼요 ?    1초가 걸릴 수도 있고 평생이 걸릴 수도 있어요 .      2
# 11390           짝남이 내가 좋아하는걸 1도 몰라 .                     1은 알게 해야죠 .      2
# 11522           짝녀가 좋아하는거 눈치 1도 못챔 .                     1은 알게 해야죠 .      2
#
# [415 rows x 3 columns]

# %% [markdown]
# - 각자 요구사항별로 전처리된 것을 확인할 수 있다.

# %% [markdown]
# - `샘플 확인`

# %%
print('전체 샘플 수 :', len(df['Q']))
print('전체 샘플 수 :', len(df['A']))

print('전처리 후의 22번째 질문 샘플: {}'.format(df['Q'][21]))
print('전처리 후의 22번째 답변 샘플: {}'.format(df['A'][21]))
# Out:
# 전체 샘플 수 : 11823
# 전체 샘플 수 : 11823
# 전처리 후의 22번째 질문 샘플: 가스비 장난 아님
# 전처리 후의 22번째 답변 샘플: 다음 달에는 더 절약해봐요 .

# %% [markdown]
# ### Step 3. SubwordTextEncoder 사용하기

# %% [markdown]
# - `단어장 만들기`

# %%
import tensorflow_datasets as tfds

# 질문과 답변 데이터셋에 대해서 Vocabulary 생성
tokenizer = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(df['Q'] + df['A'], target_vocab_size=2**13)

# 시작 토큰과 종료 토큰에 고유한 정수를 부여합니다.
START_TOKEN, END_TOKEN = [tokenizer.vocab_size], [tokenizer.vocab_size + 1]

# %% [markdown]
# - `시작, 종료 토큰 번호 확인, 사이즈 조정`

# %%
print('START_TOKEN의 번호 :' ,[tokenizer.vocab_size])
print('END_TOKEN의 번호 :' ,[tokenizer.vocab_size + 1])

# 시작 토큰과 종료 토큰을 고려하여 +2를 하여 단어장의 크기를 산정합니다.
VOCAB_SIZE = tokenizer.vocab_size + 2
# Out:
# START_TOKEN의 번호 : [8361]
# END_TOKEN의 번호 : [8362]

# %% [markdown]
# - `정수 인코딩(Integer encoding) & 패딩(Padding) 변환결과 확인`

# %%
# 임의의 22번째 샘플에 대해서 정수 인코딩 작업을 수행.
# 각 토큰을 고유한 정수로 변환
print('정수 인코딩 후의 21번째 질문 샘플: {}'.format(tokenizer.encode(df['Q'][21])))
print('정수 인코딩 후의 21번째 답변 샘플: {}'.format(tokenizer.encode(df['A'][21])))
# Out:
# 정수 인코딩 후의 21번째 질문 샘플: [5828, 606, 2500, 4174]
# 정수 인코딩 후의 21번째 답변 샘플: [2684, 7667, 8, 6377, 95, 1]

# %% [markdown]
# - `문장의 최대 길이 지정(패딩(Padding) 값`

# %% [markdown]
# - 단어장 확인
#     - 언더바의 의미
#     - 예를 들어, "게임"이라는 단어를 부분 단어로 나누면 "게_"와 "임"으로 분할될 수 있습니다. 여기서 "게_"는 "게임"의 일부를 나타내는 부분 단어입니다. 이러한 부분 단어(subword)를 사용하는 이유는 언어의 다양성에 대응하기 위함입니다. 언어에 따라서 단어의 형태가 다양하게 나타날 수 있기 때문에, 부분 단어(subword) 단위로 토큰화하면 단어의 다양한 형태를 다룰 수 있습니다.(by chat-gpt)

# %%
tokenizer.subwords
# Out:
# [' .',
#  ' ?',
#  '거예요',
#  '게_',
#  '수_',
#  '너무_',
#  '는_',
#  '더_',
#  '거_',
#  '좋아하는_',
#  '이_',
#  ' . ',
#  '을_',
#  '도_',
#  '잘_',
#  '고_',
#  '것_',
#  '요',
#  '많이_',
#  '안_',
#  '같아요',
#  '좋은_',
#  '한_',
#  '좀_',
#  '있어요',
#  '가_',
#  '은_',
#  '나_',
#  '있을_',
#  '에_',
#  '지_',
#  '해보세요',
#  '할_',
#  '사람_',
#  '면_',
#  '건_',
#  ' !',
#  '사람이_',
#  '마세요',
#  '를_',
#  '다_',
#  '하고_',
#  '하는_',
#  '보세요',
#  '해',
#  '죠',
#  '의_',
#  '서_',
#  '내가_',
#  '싶어',
#  '지',
#  '내_',
#  '네',
#  '마음이_',
#  '이제_',
#  '만_',
#  '썸_',
#  '어떻게_',
#  '어',
#  '같아',
#  '있는_',
#  '왜_',
#  '다른_',
#  '세요',
#  '나',
#  '수도_',
#  '시간이_',
#  '다시_',
#  '다',
#  '그_',
#  '것도_',
#  '또_',
#  '좋을_',
#  '오늘_',
#  '정말_',
#  '싶다',
#  '같이_',
#  '가',
#  '이',
#  '네요',
#  '될_',
#  '해요',
#  '자꾸_',
#  '걸_',
#  '없어요',
#  '하세요',
#  '로_',
#  '있어',
#  '일_',
#  '길_',
#  '바랄게요',
#  '까',
#  '돼요',
#  '에서_',
#  '봐요',
#  '하면_',
#  '할까',
#  '으로_',
#  '때_',
#  '될까',
#  '주세요',
#  '헤어진지_',
#  '먼저_',
#  '기_',
#  '진짜_',
#  '없어',
#  '나를_',
#  '고',
#  '이별_',
#  '여자친구가_',
#  '야',
#  '좋아요',
#  '있을까',
#  '제가_',
#  '마음을_',
#  '계속_',
#  '혼자_',
#  '없는_',
#  '못_',
#  '남자친구가_',
#  '해도_',
#  '드세요',
#  '기',
#  '줄_',
#  '않아요',
#  '먹고_',
#  '는데_',
#  '하지_',
#  '좋죠',
#  '저도_',
#  '일이_',
#  '아',
#  '바랍니다',
#  '데_',
#  '보고_',
#  '이별',
#  '힘든_',
#  '만큼_',
#  '생각해요',
#  '말해보세요',
#  '마음_',
#  '나봐요',
#  '그런_',
#  '주',
#  '좋겠어요',
#  '사랑이_',
#  '친구가_',
#  '연락_',
#  '습니다',
#  '사람은_',
#  '뭐_',
#  '그럴_',
#  '과_',
#  '있으면_',
#  '무슨_',
#  '대',
#  '야_',
#  '자',
#  '돼',
#  '날_',
#  '많은_',
#  '했어',
#  '좋아',
#  '인_',
#  '연애_',
#  '에요',
#  '안',
#  '몰라요',
#  '그냥_',
#  '이렇게_',
#  '예요',
#  '아직_',
#  '수',
#  '는게_',
#  '합니다',
#  '참_',
#  '어떤_',
#  '랑_',
#  '하',
#  '시간_',
#  '보',
#  '구',
#  '자신을_',
#  '서',
#  '내',
#  ' , ',
#  '사람을_',
#  '비',
#  '어떨까요',
#  '새로운_',
#  '사랑은_',
#  '리',
#  '나만_',
#  '생각해보세요',
#  '말고_',
#  '던_',
#  '타는_',
#  '같은_',
#  '하게_',
#  '인데_',
#  '사',
#  '술_',
#  '질_',
#  '살_',
#  '봐',
#  '도',
#  '가고_',
#  '해야_',
#  '생각이_',
#  '말_',
#  '짝사랑_',
#  '으면_',
#  '사랑_',
#  '좋겠네요',
#  '전_',
#  '있는데_',
#  '안돼',
#  '부',
#  '라고_',
#  '듯',
#  '긴_',
#  '아니에요',
#  '생각을_',
#  '거라_',
#  '헤어진_',
#  '연락이_',
#  '여',
#  '거',
#  '힘드네',
#  '항상_',
#  '입니다',
#  '선물_',
#  '사랑하는_',
#  '사람',
#  '들',
#  '시',
#  '면서_',
#  '나한테_',
#  '가는_',
#  '짝남이_',
#  '중',
#  '모르겠어',
#  '니_',
#  '지금_',
#  '이별을_',
#  '볼까',
#  '바라요',
#  '무',
#  '는데',
#  '그렇게_',
#  '겠죠',
#  '걸까',
#  '후_',
#  '차',
#  '저는_',
#  '때가_',
#  '나는_',
#  '그',
#  '힘들어',
#  '제_',
#  '않는_',
#  '싫어',
#  '보다_',
#  '많아',
#  '만날_',
#  '데',
#  '한',
#  '찾아보세요',
#  '저',
#  '겠어요',
#  '하죠',
#  '쉽지_',
#  '라',
#  '니',
#  '꼭_',
#  '좋겠다',
#  '올_',
#  '싶은_',
#  '마음에_',
#  '마',
#  '된_',
#  '가보세요',
#  '진_',
#  '직접_',
#  '왔어',
#  '소',
#  '말을_',
#  '따라_',
#  '돈_',
#  '괜찮아요',
#  '있죠',
#  '사랑을_',
#  '다고_',
#  '겠네요',
#  '좋을까',
#  '일',
#  '오세요',
#  '않을_',
#  '서로_',
#  '보는_',
#  '말',
#  '도움이_',
#  '대화를_',
#  '대로_',
#  '날',
#  '그게_',
#  '하나',
#  '지도_',
#  '열심히_',
#  '없이_',
#  '물어보세요',
#  '모',
#  '난_',
#  '짝남_',
#  '인',
#  '이젠_',
#  '음',
#  '때문에_',
#  '타',
#  '충분히_',
#  '좋겠어',
#  '오래_',
#  '연애',
#  '연락을_',
#  '얼른_',
#  '봅니다',
#  '말아요',
#  '만',
#  '동',
#  '데이트_',
#  '니까요',
#  '니까_',
#  '힘들_',
#  '해볼까',
#  '친구_',
#  '져',
#  '제',
#  '연락해보세요',
#  '로',
#  '해서_',
#  '함께_',
#  '큰_',
#  '짝녀가_',
#  '집에_',
#  '정',
#  '이별은_',
#  '아직도_',
#  '시간을_',
#  '바',
#  '래',
#  '히_',
#  '장',
#  '있나봐요',
#  '오늘도_',
#  '신',
#  '생각_',
#  '볼_',
#  '면',
#  '라_',
#  '내일_',
#  '결국_',
#  '게',
#  '건가',
#  ' ? ',
#  '함',
#  '조금_',
#  '제일_',
#  '의',
#  '어요',
#  '어때',
#  '않은_',
#  '사랑의_',
#  '남자_',
#  '중요한_',
#  '조금씩_',
#  '조금만_',
#  '마음의_',
#  '대한_',
#  '는',
#  '남',
#  '집_',
#  '반',
#  '남자가_',
#  '같애',
#  '갈_',
#  'ㅠ',
#  '하지',
#  '중요해요',
#  '조심하세요',
#  '요즘_',
#  '아파',
#  '싶은데_',
#  '세',
#  '살고_',
#  '사람이랑_',
#  '방법',
#  '되나',
#  '갑자기_',
#  '가장_',
#  '해_',
#  '지만_',
#  '와',
#  '여자가_',
#  '번_',
#  '뭘까',
#  '당신의_',
#  '겠지',
#  '헤어지고_',
#  '한테_',
#  '치',
#  '차_',
#  '심',
#  '상',
#  '받아',
#  '못',
#  '려',
#  '들어',
#  '되는_',
#  '공',
#  '결혼_',
#  '가요',
#  '짝남한테_',
#  '주는_',
#  '자신의_',
#  '일까',
#  '여행_',
#  '어떡해',
#  '싶어요',
#  '스',
#  '분',
#  '방법_',
#  '모르는_',
#  '매일_',
#  '들_',
#  '했는데_',
#  '하는게_',
#  '하네',
#  '줘',
#  '이에요',
#  '엄청_',
#  '나와',
#  '같은데_',
#  '가봐요',
#  '처럼_',
#  '째',
#  '정리가_',
#  '전에_',
#  '자고_',
#  '이야',
#  '오',
#  '여자',
#  '에는_',
#  '식',
#  '생각보다_',
#  '사는_',
#  '모르겠어요',
#  '라도_',
#  '딱_',
#  '됐어',
#  '다가_',
#  '나쁜_',
#  '기도_',
#  '카톡_',
#  '자주_',
#  '오늘은_',
#  '애',
#  '스트레스_',
#  '받고_',
#  '머리_',
#  '든_',
#  '되',
#  '네_',
#  '해주세요',
#  '하는데_',
#  '친구랑_',
#  '천천히_',
#  '질',
#  '이죠',
#  '어제_',
#  '시작',
#  '보면_',
#  '뭐가_',
#  '러',
#  '두',
#  '기분이_',
#  '기분_',
#  '확신이_',
#  '화',
#  '하기_',
#  '점점_',
#  '잠',
#  '잘할_',
#  '잘하고_',
#  '있다면_',
#  '유',
#  '와_',
#  '없네',
#  '양',
#  '사람한테_',
#  '밥_',
#  '뭘_',
#  '거죠',
#  '후',
#  '한달',
#  '잘',
#  '임',
#  '을',
#  '생각해',
#  '사세요',
#  '사람도_',
#  '벌써_',
#  '미',
#  '만나고_',
#  '덜_',
#  '나서_',
#  '깨',
#  '것',
#  '간',
#  '가서_',
#  '힘내세요',
#  '핸드폰_',
#  '지는_',
#  '전',
#  '잘하는_',
#  '이유가_',
#  '을까',
#  '여자친구_',
#  '없을_',
#  '알_',
#  '아_',
#  '쉬운_',
#  '살',
#  '사랑',
#  '사람들이_',
#  '뿐이에요',
#  '빨리_',
#  '부터_',
#  '먹',
#  '러_',
#  '당신을_',
#  '그래도_',
#  '공부_',
#  '걸',
#  '힘들다',
#  '해봐요',
#  '할',
#  '피',
#  '진',
#  '좀',
#  '조',
#  '적인_',
#  '일찍_',
#  '우리_',
#  '쓰',
#  '쉬',
#  '서로에게_',
#  '생각나',
#  '생',
#  '사랑에_',
#  '방',
#  '믿어요',
#  '몸',
#  '많았어요',
#  '만에_',
#  '만나',
#  '당신이_',
#  '눈을_',
#  '냐',
#  '남자친구_',
#  '군요',
#  '간다',
#  '했던_',
#  '저랑_',
#  '자신이_',
#  '인지_',
#  '연락',
#  '언젠간_',
#  '야지',
#  '않죠',
#  '안해',
#  '아닌_',
#  '설레',
#  '사귀고_',
#  '모두_',
#  '매',
#  '런_',
#  '되지_',
#  '되길_',
#  '단',
#  '나봐',
#  '나도_',
#  '기가_',
#  '그만_',
#  '감',
#  '필요한_',
#  '트',
#  '좋아할_',
#  '절',
#  '재',
#  '있었나봐요',
#  '인연이_',
#  '이야기',
#  '이런_',
#  '신경쓰지_',
#  '사랑해',
#  '비_',
#  '발',
#  '물_',
#  '맞는_',
#  '만나는_',
#  '마지막_',
#  '려_',
#  '달',
#  '놀',
#  '남자',
#  '끝나',
#  '까지_',
#  '길',
#  '곳으로_',
#  '건',
#  '거나_',
#  '힘이_',
#  '한번_',
#  '째_',
#  '줄',
#  '이별한지_',
#  '이나_',
#  '으면',
#  '위해_',
#  '연락하고_',
#  '여친_',
#  '여자_',
#  '없죠',
#  '아무래도_',
#  '아무것도_',
#  '아니',
#  '아는_',
#  '별',
#  '뭐야',
#  '문',
#  '못하겠어',
#  '맞',
#  '달라고_',
#  '괜찮은_',
#  '관심_',
#  '건지_',
#  '개',
#  '하나씩_',
#  '짝녀_',
#  '중에_',
#  '주무세요',
#  '좋아해',
#  '잠시_',
#  '인가봐요',
#  '여친이_',
#  '에',
#  '알았는데',
#  '알아',
#  '않아',
#  '안나',
#  '싶네요',
#  '슬픈_',
#  '생각',
#  '배',
#  '반_',
#  '모든_',
#  '몇_',
#  '명',
#  '많아요',
#  '때까지_',
#  '니다',
#  '눈이_',
#  '날이_',
#  '기억',
#  '귀찮아',
#  '괜찮을까',
#  '곧_',
#  '고민',
#  '같은데',
#  '감기_',
#  '가끔_',
#  '호',
#  '필요해요',
#  '크',
#  '준비_',
#  '좋아하면_',
#  '잔_',
#  '있나',
#  '인가',
#  '으',
#  '울',
#  '욕',
#  '예의가_',
#  '애가_',
#  '애_',
#  '않아도_',
#  '사귀는_',
#  '보내',
#  '받',
#  '말이_',
#  '만났어',
#  '따',
#  '당',
#  '늦지_',
#  '남친_',
#  '끝',
#  '경',
#  '거야',
#  '강',
#  '가져보세요',
#  '힘들게_',
#  '확인해보세요',
#  '헤어졌습니다',
#  '편이_',
#  '지금은_',
#  '좋아하게_',
#  '잡',
#  '있습니다',
#  '일을_',
#  '이네요',
#  '원',
#  '운_',
#  '없네요',
#  '아픈_',
#  '살펴보세요',
#  '사진_',
#  '사랑했던_',
#  '복',
#  '보여',
#  '별_',
#  '미리_',
#  '맛있게_',
#  '맘_',
#  '되네',
#  '데이트',
#  '남편이_',
#  '난',
#  '나중에_',
#  '꿈에_',
#  '그녀를_',
#  '궁금해',
#  '과',
#  '것이_',
#  '감정을_',
#  '갈',
#  '가세요',
#  '힘들죠',
#  '힘들',
#  '허',
#  '행동',
#  '해야지',
#  '한다',
#  '하루_',
#  '편',
#  '친구한테_',
#  '취',
#  '추억',
#  '짝녀한테_',
#  '중인데_',
#  '중요하지_',
#  '좋다',
#  '장_',
#  '잠이_',
#  '일은_',
#  '은',
#  '위',
#  '원하는_',
#  '오늘',
#  '예쁘게_',
#  '예',
#  '언제나_',
#  '언제_',
#  '알',
#  '아니라_',
#  '실_',
#  '시간',
#  '쉬고_',
#  '사랑해주세요',
#  '보통_',
#  '변화가_',
#  '받을_',
#  '밖에_',
#  '뭐',
#  '맨날_',
#  '라면_',
#  '돌',
#  '느낌',
#  '노래_',
#  '남자애가_',
#  '나봅니다',
#  '긴',
#  '금',
#  '관심이_',
#  '고민이야',
#  '계',
#  '겠다',
#  '가면_',
#  '가기_',
#  '힘들어요',
#  '확실한_',
#  '탈_',
#  '친구',
#  '초',
#  '쳐',
#  '짝남이랑_',
#  '집',
#  '즐거운_',
#  '졌어',
#  '작은_',
#  '자기_',
#  '있는지_',
#  '입',
#  '이별후_',
#  '이별이_',
#  '워',
#  '우',
#  '완전_',
#  '없다면_',
#  '알려줘',
#  '알게_',
#  '썸남_',
#  '수록_',
#  '성',
#  '새',
#  '불',
#  '바로_',
#  '물',
#  '먹으면_',
#  '만나지_',
#  '마요',
#  '때는_',
#  '당신은_',
#  '다니',
#  '다는_',
#  '누구나_',
#  '노',
#  '나요',
#  '나가',
#  '꾸',
#  '그래요',
#  '겠어',
#  '걸로_',
#  '같습니다',
#  ' ! !',
#  '휴',
#  '행복해',
#  '하네요',
#  '필요해',
#  '텐데',
#  '타고_',
#  '커피_',
#  '친구를_',
#  '주고_',
#  '좋은',
#  '좋겠죠',
#  '적',
#  '에게_',
#  '않고_',
#  '아무_',
#  '썸',
#  '싫다',
#  '스스로_',
#  '선',
#  '생길_',
#  '상관_',
#  '밤',
#  '멋진_',
#  '르',
#  '려고_',
#  '때도_',
#  '드는_',
#  '돈이_',
#  '다를_',
#  '놓',
#  '너_',
#  '까_',
#  '금방_',
#  '결혼',
#  '갈까',
#  '가능',
#  '혼',
#  '했',
#  '하면서_',
#  '하다',
#  '통',
#  '추',
#  '지금도_',
#  '준_',
#  '전화',
#  '자신',
#  '이야기_',
#  '이별이',
#  '용',
#  '오는_',
#  '연락해도_',
#  '여자애가_',
#  '었어',
#  '얼굴_',
#  '어려워',
#  '어느덧_',
#  '약_',
#  '않길_',
#  '안녕',
#  '아닐까요',
#  '아닌데_',
#  '싸',
#  '실',
#  '시험_',
#  '술',
#  '사랑하고_',
#  '받는_',
#  '망',
#  '맛있는_',
#  '란_',
#  '라는_',
#  '떨려',
#  '드디어_',
#  '동안_',
#  '는거_',
#  '너',
#  '꺼',
#  '기대',
#  '고민_',
#  '같네요',
#  '감정',
#  '가지고_',
#  '가슴이_',
#  '힘들겠지만_',
#  '헤어짐',
#  '했다',
#  '카톡',
#  '천',
#  '참',
#  '지나',
#  '좋아하는게_',
#  '좋아하',
#  '절대_',
#  '자연스러운_',
#  '자_',
#  '있었',
#  '인사',
#  '이유',
#  '이별의_',
#  '오래',
#  '영화_',
#  '연',
#  '어서_',
#  '앞에_',
#  '알고_',
#  '아닌지_',
#  '써',
#  '신경_',
#  '시간은_',
#  '소개팅_',
#  '설',
#  '사이',
#  '사랑하면_',
#  '사람에_',
#  '보지_',
#  '번',
#  '받아들이는_',
#  '바람',
#  '미련이_',
#  '미련',
#  '뭔지_',
#  '뭐라고_',
#  '물어보는_',
#  '문제가_',
#  '무서워',
#  '못하는_',
#  '몸이_',
#  '마음은_',
#  '마음도_',
#  '마음',
#  '마시',
#  '디',
#  '더니_',
#  '다면_',
#  '눈',
#  '누구',
#  '놈',
#  '근',
#  '그리고_',
#  '교',
#  '고민이_',
#  '같네',
#  '1년',
#  '힘들겠어요',
#  '했는데',
#  '한달_',
#  '학교_',
#  '하는데',
#  '폰_',
#  '카',
#  '충분한_',
#  '축하해요',
#  '짝남',
#  '짐',
#  '직',
#  '준비가_',
#  ...]

# %% [markdown]
# - 문장 길이 결정용 vocab제작 : 언더바를 제거하고 단어들을 통해 개수를 구해본다.

# %%
vocab = tokenizer.subwords
vocab = [x.replace("_","") for x in vocab]
print(len(vocab))
vocab
# Out:
# 8104
# [' .',
#  ' ?',
#  '거예요',
#  '게',
#  '수',
#  '너무',
#  '는',
#  '더',
#  '거',
#  '좋아하는',
#  '이',
#  ' . ',
#  '을',
#  '도',
#  '잘',
#  '고',
#  '것',
#  '요',
#  '많이',
#  '안',
#  '같아요',
#  '좋은',
#  '한',
#  '좀',
#  '있어요',
#  '가',
#  '은',
#  '나',
#  '있을',
#  '에',
#  '지',
#  '해보세요',
#  '할',
#  '사람',
#  '면',
#  '건',
#  ' !',
#  '사람이',
#  '마세요',
#  '를',
#  '다',
#  '하고',
#  '하는',
#  '보세요',
#  '해',
#  '죠',
#  '의',
#  '서',
#  '내가',
#  '싶어',
#  '지',
#  '내',
#  '네',
#  '마음이',
#  '이제',
#  '만',
#  '썸',
#  '어떻게',
#  '어',
#  '같아',
#  '있는',
#  '왜',
#  '다른',
#  '세요',
#  '나',
#  '수도',
#  '시간이',
#  '다시',
#  '다',
#  '그',
#  '것도',
#  '또',
#  '좋을',
#  '오늘',
#  '정말',
#  '싶다',
#  '같이',
#  '가',
#  '이',
#  '네요',
#  '될',
#  '해요',
#  '자꾸',
#  '걸',
#  '없어요',
#  '하세요',
#  '로',
#  '있어',
#  '일',
#  '길',
#  '바랄게요',
#  '까',
#  '돼요',
#  '에서',
#  '봐요',
#  '하면',
#  '할까',
#  '으로',
#  '때',
#  '될까',
#  '주세요',
#  '헤어진지',
#  '먼저',
#  '기',
#  '진짜',
#  '없어',
#  '나를',
#  '고',
#  '이별',
#  '여자친구가',
#  '야',
#  '좋아요',
#  '있을까',
#  '제가',
#  '마음을',
#  '계속',
#  '혼자',
#  '없는',
#  '못',
#  '남자친구가',
#  '해도',
#  '드세요',
#  '기',
#  '줄',
#  '않아요',
#  '먹고',
#  '는데',
#  '하지',
#  '좋죠',
#  '저도',
#  '일이',
#  '아',
#  '바랍니다',
#  '데',
#  '보고',
#  '이별',
#  '힘든',
#  '만큼',
#  '생각해요',
#  '말해보세요',
#  '마음',
#  '나봐요',
#  '그런',
#  '주',
#  '좋겠어요',
#  '사랑이',
#  '친구가',
#  '연락',
#  '습니다',
#  '사람은',
#  '뭐',
#  '그럴',
#  '과',
#  '있으면',
#  '무슨',
#  '대',
#  '야',
#  '자',
#  '돼',
#  '날',
#  '많은',
#  '했어',
#  '좋아',
#  '인',
#  '연애',
#  '에요',
#  '안',
#  '몰라요',
#  '그냥',
#  '이렇게',
#  '예요',
#  '아직',
#  '수',
#  '는게',
#  '합니다',
#  '참',
#  '어떤',
#  '랑',
#  '하',
#  '시간',
#  '보',
#  '구',
#  '자신을',
#  '서',
#  '내',
#  ' , ',
#  '사람을',
#  '비',
#  '어떨까요',
#  '새로운',
#  '사랑은',
#  '리',
#  '나만',
#  '생각해보세요',
#  '말고',
#  '던',
#  '타는',
#  '같은',
#  '하게',
#  '인데',
#  '사',
#  '술',
#  '질',
#  '살',
#  '봐',
#  '도',
#  '가고',
#  '해야',
#  '생각이',
#  '말',
#  '짝사랑',
#  '으면',
#  '사랑',
#  '좋겠네요',
#  '전',
#  '있는데',
#  '안돼',
#  '부',
#  '라고',
#  '듯',
#  '긴',
#  '아니에요',
#  '생각을',
#  '거라',
#  '헤어진',
#  '연락이',
#  '여',
#  '거',
#  '힘드네',
#  '항상',
#  '입니다',
#  '선물',
#  '사랑하는',
#  '사람',
#  '들',
#  '시',
#  '면서',
#  '나한테',
#  '가는',
#  '짝남이',
#  '중',
#  '모르겠어',
#  '니',
#  '지금',
#  '이별을',
#  '볼까',
#  '바라요',
#  '무',
#  '는데',
#  '그렇게',
#  '겠죠',
#  '걸까',
#  '후',
#  '차',
#  '저는',
#  '때가',
#  '나는',
#  '그',
#  '힘들어',
#  '제',
#  '않는',
#  '싫어',
#  '보다',
#  '많아',
#  '만날',
#  '데',
#  '한',
#  '찾아보세요',
#  '저',
#  '겠어요',
#  '하죠',
#  '쉽지',
#  '라',
#  '니',
#  '꼭',
#  '좋겠다',
#  '올',
#  '싶은',
#  '마음에',
#  '마',
#  '된',
#  '가보세요',
#  '진',
#  '직접',
#  '왔어',
#  '소',
#  '말을',
#  '따라',
#  '돈',
#  '괜찮아요',
#  '있죠',
#  '사랑을',
#  '다고',
#  '겠네요',
#  '좋을까',
#  '일',
#  '오세요',
#  '않을',
#  '서로',
#  '보는',
#  '말',
#  '도움이',
#  '대화를',
#  '대로',
#  '날',
#  '그게',
#  '하나',
#  '지도',
#  '열심히',
#  '없이',
#  '물어보세요',
#  '모',
#  '난',
#  '짝남',
#  '인',
#  '이젠',
#  '음',
#  '때문에',
#  '타',
#  '충분히',
#  '좋겠어',
#  '오래',
#  '연애',
#  '연락을',
#  '얼른',
#  '봅니다',
#  '말아요',
#  '만',
#  '동',
#  '데이트',
#  '니까요',
#  '니까',
#  '힘들',
#  '해볼까',
#  '친구',
#  '져',
#  '제',
#  '연락해보세요',
#  '로',
#  '해서',
#  '함께',
#  '큰',
#  '짝녀가',
#  '집에',
#  '정',
#  '이별은',
#  '아직도',
#  '시간을',
#  '바',
#  '래',
#  '히',
#  '장',
#  '있나봐요',
#  '오늘도',
#  '신',
#  '생각',
#  '볼',
#  '면',
#  '라',
#  '내일',
#  '결국',
#  '게',
#  '건가',
#  ' ? ',
#  '함',
#  '조금',
#  '제일',
#  '의',
#  '어요',
#  '어때',
#  '않은',
#  '사랑의',
#  '남자',
#  '중요한',
#  '조금씩',
#  '조금만',
#  '마음의',
#  '대한',
#  '는',
#  '남',
#  '집',
#  '반',
#  '남자가',
#  '같애',
#  '갈',
#  'ㅠ',
#  '하지',
#  '중요해요',
#  '조심하세요',
#  '요즘',
#  '아파',
#  '싶은데',
#  '세',
#  '살고',
#  '사람이랑',
#  '방법',
#  '되나',
#  '갑자기',
#  '가장',
#  '해',
#  '지만',
#  '와',
#  '여자가',
#  '번',
#  '뭘까',
#  '당신의',
#  '겠지',
#  '헤어지고',
#  '한테',
#  '치',
#  '차',
#  '심',
#  '상',
#  '받아',
#  '못',
#  '려',
#  '들어',
#  '되는',
#  '공',
#  '결혼',
#  '가요',
#  '짝남한테',
#  '주는',
#  '자신의',
#  '일까',
#  '여행',
#  '어떡해',
#  '싶어요',
#  '스',
#  '분',
#  '방법',
#  '모르는',
#  '매일',
#  '들',
#  '했는데',
#  '하는게',
#  '하네',
#  '줘',
#  '이에요',
#  '엄청',
#  '나와',
#  '같은데',
#  '가봐요',
#  '처럼',
#  '째',
#  '정리가',
#  '전에',
#  '자고',
#  '이야',
#  '오',
#  '여자',
#  '에는',
#  '식',
#  '생각보다',
#  '사는',
#  '모르겠어요',
#  '라도',
#  '딱',
#  '됐어',
#  '다가',
#  '나쁜',
#  '기도',
#  '카톡',
#  '자주',
#  '오늘은',
#  '애',
#  '스트레스',
#  '받고',
#  '머리',
#  '든',
#  '되',
#  '네',
#  '해주세요',
#  '하는데',
#  '친구랑',
#  '천천히',
#  '질',
#  '이죠',
#  '어제',
#  '시작',
#  '보면',
#  '뭐가',
#  '러',
#  '두',
#  '기분이',
#  '기분',
#  '확신이',
#  '화',
#  '하기',
#  '점점',
#  '잠',
#  '잘할',
#  '잘하고',
#  '있다면',
#  '유',
#  '와',
#  '없네',
#  '양',
#  '사람한테',
#  '밥',
#  '뭘',
#  '거죠',
#  '후',
#  '한달',
#  '잘',
#  '임',
#  '을',
#  '생각해',
#  '사세요',
#  '사람도',
#  '벌써',
#  '미',
#  '만나고',
#  '덜',
#  '나서',
#  '깨',
#  '것',
#  '간',
#  '가서',
#  '힘내세요',
#  '핸드폰',
#  '지는',
#  '전',
#  '잘하는',
#  '이유가',
#  '을까',
#  '여자친구',
#  '없을',
#  '알',
#  '아',
#  '쉬운',
#  '살',
#  '사랑',
#  '사람들이',
#  '뿐이에요',
#  '빨리',
#  '부터',
#  '먹',
#  '러',
#  '당신을',
#  '그래도',
#  '공부',
#  '걸',
#  '힘들다',
#  '해봐요',
#  '할',
#  '피',
#  '진',
#  '좀',
#  '조',
#  '적인',
#  '일찍',
#  '우리',
#  '쓰',
#  '쉬',
#  '서로에게',
#  '생각나',
#  '생',
#  '사랑에',
#  '방',
#  '믿어요',
#  '몸',
#  '많았어요',
#  '만에',
#  '만나',
#  '당신이',
#  '눈을',
#  '냐',
#  '남자친구',
#  '군요',
#  '간다',
#  '했던',
#  '저랑',
#  '자신이',
#  '인지',
#  '연락',
#  '언젠간',
#  '야지',
#  '않죠',
#  '안해',
#  '아닌',
#  '설레',
#  '사귀고',
#  '모두',
#  '매',
#  '런',
#  '되지',
#  '되길',
#  '단',
#  '나봐',
#  '나도',
#  '기가',
#  '그만',
#  '감',
#  '필요한',
#  '트',
#  '좋아할',
#  '절',
#  '재',
#  '있었나봐요',
#  '인연이',
#  '이야기',
#  '이런',
#  '신경쓰지',
#  '사랑해',
#  '비',
#  '발',
#  '물',
#  '맞는',
#  '만나는',
#  '마지막',
#  '려',
#  '달',
#  '놀',
#  '남자',
#  '끝나',
#  '까지',
#  '길',
#  '곳으로',
#  '건',
#  '거나',
#  '힘이',
#  '한번',
#  '째',
#  '줄',
#  '이별한지',
#  '이나',
#  '으면',
#  '위해',
#  '연락하고',
#  '여친',
#  '여자',
#  '없죠',
#  '아무래도',
#  '아무것도',
#  '아니',
#  '아는',
#  '별',
#  '뭐야',
#  '문',
#  '못하겠어',
#  '맞',
#  '달라고',
#  '괜찮은',
#  '관심',
#  '건지',
#  '개',
#  '하나씩',
#  '짝녀',
#  '중에',
#  '주무세요',
#  '좋아해',
#  '잠시',
#  '인가봐요',
#  '여친이',
#  '에',
#  '알았는데',
#  '알아',
#  '않아',
#  '안나',
#  '싶네요',
#  '슬픈',
#  '생각',
#  '배',
#  '반',
#  '모든',
#  '몇',
#  '명',
#  '많아요',
#  '때까지',
#  '니다',
#  '눈이',
#  '날이',
#  '기억',
#  '귀찮아',
#  '괜찮을까',
#  '곧',
#  '고민',
#  '같은데',
#  '감기',
#  '가끔',
#  '호',
#  '필요해요',
#  '크',
#  '준비',
#  '좋아하면',
#  '잔',
#  '있나',
#  '인가',
#  '으',
#  '울',
#  '욕',
#  '예의가',
#  '애가',
#  '애',
#  '않아도',
#  '사귀는',
#  '보내',
#  '받',
#  '말이',
#  '만났어',
#  '따',
#  '당',
#  '늦지',
#  '남친',
#  '끝',
#  '경',
#  '거야',
#  '강',
#  '가져보세요',
#  '힘들게',
#  '확인해보세요',
#  '헤어졌습니다',
#  '편이',
#  '지금은',
#  '좋아하게',
#  '잡',
#  '있습니다',
#  '일을',
#  '이네요',
#  '원',
#  '운',
#  '없네요',
#  '아픈',
#  '살펴보세요',
#  '사진',
#  '사랑했던',
#  '복',
#  '보여',
#  '별',
#  '미리',
#  '맛있게',
#  '맘',
#  '되네',
#  '데이트',
#  '남편이',
#  '난',
#  '나중에',
#  '꿈에',
#  '그녀를',
#  '궁금해',
#  '과',
#  '것이',
#  '감정을',
#  '갈',
#  '가세요',
#  '힘들죠',
#  '힘들',
#  '허',
#  '행동',
#  '해야지',
#  '한다',
#  '하루',
#  '편',
#  '친구한테',
#  '취',
#  '추억',
#  '짝녀한테',
#  '중인데',
#  '중요하지',
#  '좋다',
#  '장',
#  '잠이',
#  '일은',
#  '은',
#  '위',
#  '원하는',
#  '오늘',
#  '예쁘게',
#  '예',
#  '언제나',
#  '언제',
#  '알',
#  '아니라',
#  '실',
#  '시간',
#  '쉬고',
#  '사랑해주세요',
#  '보통',
#  '변화가',
#  '받을',
#  '밖에',
#  '뭐',
#  '맨날',
#  '라면',
#  '돌',
#  '느낌',
#  '노래',
#  '남자애가',
#  '나봅니다',
#  '긴',
#  '금',
#  '관심이',
#  '고민이야',
#  '계',
#  '겠다',
#  '가면',
#  '가기',
#  '힘들어요',
#  '확실한',
#  '탈',
#  '친구',
#  '초',
#  '쳐',
#  '짝남이랑',
#  '집',
#  '즐거운',
#  '졌어',
#  '작은',
#  '자기',
#  '있는지',
#  '입',
#  '이별후',
#  '이별이',
#  '워',
#  '우',
#  '완전',
#  '없다면',
#  '알려줘',
#  '알게',
#  '썸남',
#  '수록',
#  '성',
#  '새',
#  '불',
#  '바로',
#  '물',
#  '먹으면',
#  '만나지',
#  '마요',
#  '때는',
#  '당신은',
#  '다니',
#  '다는',
#  '누구나',
#  '노',
#  '나요',
#  '나가',
#  '꾸',
#  '그래요',
#  '겠어',
#  '걸로',
#  '같습니다',
#  ' ! !',
#  '휴',
#  '행복해',
#  '하네요',
#  '필요해',
#  '텐데',
#  '타고',
#  '커피',
#  '친구를',
#  '주고',
#  '좋은',
#  '좋겠죠',
#  '적',
#  '에게',
#  '않고',
#  '아무',
#  '썸',
#  '싫다',
#  '스스로',
#  '선',
#  '생길',
#  '상관',
#  '밤',
#  '멋진',
#  '르',
#  '려고',
#  '때도',
#  '드는',
#  '돈이',
#  '다를',
#  '놓',
#  '너',
#  '까',
#  '금방',
#  '결혼',
#  '갈까',
#  '가능',
#  '혼',
#  '했',
#  '하면서',
#  '하다',
#  '통',
#  '추',
#  '지금도',
#  '준',
#  '전화',
#  '자신',
#  '이야기',
#  '이별이',
#  '용',
#  '오는',
#  '연락해도',
#  '여자애가',
#  '었어',
#  '얼굴',
#  '어려워',
#  '어느덧',
#  '약',
#  '않길',
#  '안녕',
#  '아닐까요',
#  '아닌데',
#  '싸',
#  '실',
#  '시험',
#  '술',
#  '사랑하고',
#  '받는',
#  '망',
#  '맛있는',
#  '란',
#  '라는',
#  '떨려',
#  '드디어',
#  '동안',
#  '는거',
#  '너',
#  '꺼',
#  '기대',
#  '고민',
#  '같네요',
#  '감정',
#  '가지고',
#  '가슴이',
#  '힘들겠지만',
#  '헤어짐',
#  '했다',
#  '카톡',
#  '천',
#  '참',
#  '지나',
#  '좋아하는게',
#  '좋아하',
#  '절대',
#  '자연스러운',
#  '자',
#  '있었',
#  '인사',
#  '이유',
#  '이별의',
#  '오래',
#  '영화',
#  '연',
#  '어서',
#  '앞에',
#  '알고',
#  '아닌지',
#  '써',
#  '신경',
#  '시간은',
#  '소개팅',
#  '설',
#  '사이',
#  '사랑하면',
#  '사람에',
#  '보지',
#  '번',
#  '받아들이는',
#  '바람',
#  '미련이',
#  '미련',
#  '뭔지',
#  '뭐라고',
#  '물어보는',
#  '문제가',
#  '무서워',
#  '못하는',
#  '몸이',
#  '마음은',
#  '마음도',
#  '마음',
#  '마시',
#  '디',
#  '더니',
#  '다면',
#  '눈',
#  '누구',
#  '놈',
#  '근',
#  '그리고',
#  '교',
#  '고민이',
#  '같네',
#  '1년',
#  '힘들겠어요',
#  '했는데',
#  '한달',
#  '학교',
#  '하는데',
#  '폰',
#  '카',
#  '충분한',
#  '축하해요',
#  '짝남',
#  '짐',
#  '직',
#  '준비가',
#  ...]

# %% [markdown]
# - 문장 개수 세기용 메서드 정의

# %%
def len_word(word) :
    answer = 0
    for i in word.split(' '):
        if i in vocab:
            answer += 1
            
    return answer

# %%
df_len = df.copy()
df_len['Q'] = df_len['Q'].apply(lambda x:len_word(x))
df_len['A'] = df_len['A'].apply(lambda x:len_word(x))

# %%
sns.boxplot(df_len['Q'])
plt.title('Question')
plt.show()
plt.title('Answer')
sns.boxplot(df_len['A'])
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - 각각 8 쯔음을 벗어나면 이상치라 판단. 기존 노드였던 `max_length = 40을 해도 무리`가 없다고 판단

# %%
# 샘플의 최대 허용 길이 또는 패딩 후의 최종 길이
MAX_LENGTH = 40

def tokenize_and_filter(inputs, outputs):
    tokenized_inputs, tokenized_outputs = [], []

    for (sentence1, sentence2) in zip(inputs, outputs):
        # 정수 인코딩 과정에서 시작 토큰과 종료 토큰을 추가
        sentence1 = START_TOKEN + tokenizer.encode(sentence1) + END_TOKEN
        sentence2 = START_TOKEN + tokenizer.encode(sentence2) + END_TOKEN

    # 최대 길이 40 이하인 경우에만 데이터셋으로 허용
    if len(sentence1) <= MAX_LENGTH and len(sentence2) <= MAX_LENGTH:
        tokenized_inputs.append(sentence1)
        tokenized_outputs.append(sentence2)

    # 최대 길이 40으로 모든 데이터셋을 패딩
    tokenized_inputs = tf.keras.preprocessing.sequence.pad_sequences(tokenized_inputs, maxlen=MAX_LENGTH, padding='post')
    tokenized_outputs = tf.keras.preprocessing.sequence.pad_sequences(tokenized_outputs, maxlen=MAX_LENGTH, padding='post')

    return tokenized_inputs, tokenized_outputs

# %%
questions, answers = tokenize_and_filter(df['Q'], df['A'])
print('단어장의 크기 :',(VOCAB_SIZE))
print('필터링 후의 질문 샘플 개수: {}'.format(len(questions)))
print('필터링 후의 답변 샘플 개수: {}'.format(len(answers)))
# Out:
# 단어장의 크기 : 8363
# 필터링 후의 질문 샘플 개수: 1
# 필터링 후의 답변 샘플 개수: 1

# %% [markdown]
# - 그렇지만 결과가 이상하다....

# %% [markdown]
# - 알고봤더니 가져오다 인덴트가 잘못된 것 같다.

# %%
# 샘플의 최대 허용 길이 또는 패딩 후의 최종 길이
MAX_LENGTH = 40

def tokenize_and_filter(inputs, outputs):
    tokenized_inputs, tokenized_outputs = [], []

    for (sentence1, sentence2) in zip(inputs, outputs):
        # 정수 인코딩 과정에서 시작 토큰과 종료 토큰을 추가
        sentence1 = START_TOKEN + tokenizer.encode(sentence1) + END_TOKEN
        sentence2 = START_TOKEN + tokenizer.encode(sentence2) + END_TOKEN

        # 최대 길이 40 이하인 경우에만 데이터셋으로 허용
        if len(sentence1) <= MAX_LENGTH and len(sentence2) <= MAX_LENGTH:
            tokenized_inputs.append(sentence1)
            tokenized_outputs.append(sentence2)

    # 최대 길이 40으로 모든 데이터셋을 패딩
    tokenized_inputs = tf.keras.preprocessing.sequence.pad_sequences(tokenized_inputs, maxlen=MAX_LENGTH, padding='post')
    tokenized_outputs = tf.keras.preprocessing.sequence.pad_sequences(tokenized_outputs, maxlen=MAX_LENGTH, padding='post')

    return tokenized_inputs, tokenized_outputs

# %%
questions, answers = tokenize_and_filter(df['Q'], df['A'])
print('단어장의 크기 :',(VOCAB_SIZE))
print('필터링 후의 질문 샘플 개수: {}'.format(len(questions)))
print('필터링 후의 답변 샘플 개수: {}'.format(len(answers)))
# Out:
# 단어장의 크기 : 8363
# 필터링 후의 질문 샘플 개수: 11823
# 필터링 후의 답변 샘플 개수: 11823

# %% [markdown]
# - `max30일때 11822, 50일때 11823으로 차이가 없어 40으로 진행합니다.`

# %% [markdown]
# - `교사 강요` 사용
#     - t시점 예측 값을 t+1 입력으로 사용하지 않고, t+1시점 정답을 사용

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 20000

# 디코더는 이전의 target을 다음의 input으로 사용합니다.
# 이에 따라 outputs에서는 START_TOKEN을 제거하겠습니다.
dataset = tf.data.Dataset.from_tensor_slices((
  {
      'inputs': questions,
      'dec_inputs': answers[:, :-1] # end_token 제거
  },
  {
      'outputs': answers[:, 1:] # start_token 제거
  },
))

dataset = dataset.cache()
dataset = dataset.shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE)
dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ### Step 4. 모델 구성하기

# %% [markdown]
# #### 1) 포지셔널 인코딩, 어텐션, 마스킹 만들기

# %% [markdown]
# - `포지셔널 인코딩`

# %%
## 클래스 구현
# 포지셔널 인코딩 레이어
class PositionalEncoding(tf.keras.layers.Layer):

    def __init__(self, position, d_model):
        super(PositionalEncoding, self).__init__()
        self.pos_encoding = self.positional_encoding(position, d_model)

    def get_angles(self, position, i, d_model):
        angles = 1 / tf.pow(10000, (2 * (i // 2)) / tf.cast(d_model, tf.float32)) # (d_model값)
        return position * angles # (position값, d_model값) # 브로드캐스트

    def positional_encoding(self, position, d_model):
        # 각도 배열 생성
        angle_rads = self.get_angles(
            position=tf.range(position, dtype=tf.float32)[:, tf.newaxis],
            i=tf.range(d_model, dtype=tf.float32)[tf.newaxis, :],
            d_model=d_model) # position, i shape는 각각 (position값, 1), (1, d_model값)

        # 배열의 짝수 인덱스에는 sin 함수 적용
        sines = tf.math.sin(angle_rads[:, 0::2]) # (position값, d_model값/2)

        # 배열의 홀수 인덱스에는 cosine 함수 적용
        cosines = tf.math.cos(angle_rads[:, 1::2]) # (position값, d_model값/2)

        # sin과 cosine이 교차되도록 재배열
        pos_encoding = tf.stack([sines, cosines], axis=0) # (2, position값, d_model값/2)
        pos_encoding = tf.transpose(pos_encoding,[1, 2, 0]) # (position값, d_model값/2, 2)
        pos_encoding = tf.reshape(pos_encoding, [position, d_model]) # (position값, d_model값) 다시 교차됨!

        pos_encoding = pos_encoding[tf.newaxis, ...] # (1, position값, d_model값)
        return tf.cast(pos_encoding, tf.float32)

    def call(self, inputs):
        return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# %% [markdown]
# - 확인(예시 pos=5, d_model=512)

# %%
sample_pos_encoding = PositionalEncoding(50, 512)
plt.pcolormesh(sample_pos_encoding.pos_encoding.numpy()[0], cmap='RdBu')
plt.xlabel('Depth')
plt.xlim((0, 512))
plt.ylabel('Position')
plt.colorbar()
plt.show()

# %% [markdown]
# - `어텐션 레이어`

# %% [markdown]
# - 단일 어텐션

# %%
def scaled_dot_product_attention(query, key, value, mask):
    # 어텐션 가중치는 Q와 K의 닷 프로덕트
    matmul_qk = tf.matmul(query, key, transpose_b=True) # 행렬내적, b전치

    # 가중치를 정규화
    depth = tf.cast(tf.shape(key)[-1], tf.float32) # key 행개수
    logits = matmul_qk / tf.math.sqrt(depth)

    # 패딩에 마스크 추가(특정 단어 무시)
    if mask is not None:
        logits += (mask * -1e9) # 무한한 음수값

    # softmax적용
    attention_weights = tf.nn.softmax(logits, axis=-1)

    # 최종 어텐션은 가중치와 V의 닷 프로덕트
    output = tf.matmul(attention_weights, value)
    return output

# %% [markdown]
# - 멀티 헤드 어텐션

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
  
    def __init__(self, d_model, num_heads, name="multi_head_attention"):
        super(MultiHeadAttention, self).__init__(name=name)
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads # 각 어텐션별 뎁스

        self.query_dense = tf.keras.layers.Dense(units=d_model)
        self.key_dense = tf.keras.layers.Dense(units=d_model)
        self.value_dense = tf.keras.layers.Dense(units=d_model)

        self.dense = tf.keras.layers.Dense(units=d_model)

    def split_heads(self, inputs, batch_size):
        inputs = tf.reshape(inputs, shape=(batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(inputs, perm=[0, 2, 1, 3])

    def call(self, inputs):
        query, key, value, mask = inputs['query'], inputs['key'], inputs[
          'value'], inputs['mask']
        batch_size = tf.shape(query)[0]

        # Q, K, V에 각각 Dense를 적용합니다
        query = self.query_dense(query)
        key = self.key_dense(key)
        value = self.value_dense(value)

        # 병렬 연산을 위한 머리를 여러 개 만듭니다
        query = self.split_heads(query, batch_size)
        key = self.split_heads(key, batch_size)
        value = self.split_heads(value, batch_size)

        # 스케일드 닷 프로덕트 어텐션 함수
        scaled_attention = scaled_dot_product_attention(query, key, value, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

        # 어텐션 연산 후에 각 결과를 다시 연결(concatenate)합니다
        concat_attention = tf.reshape(scaled_attention,
                                    (batch_size, -1, self.d_model))

        # 최종 결과에도 Dense를 한 번 더 적용합니다
        outputs = self.dense(concat_attention)

        return outputs

# %% [markdown]
# - `마스킹`

# %% [markdown]
# - 패딩 마스킹(Padding Masking)

# %%
def create_padding_mask(x):
    mask = tf.cast(tf.math.equal(x, 0), tf.float32)
    return mask[:, tf.newaxis, tf.newaxis, :] # (batch_size, 1, 1, sequence length)

# %% [markdown]
# - 룩 어헤드 마스킹(Look-ahead masking)

# %%
def create_look_ahead_mask(x):
    seq_len = tf.shape(x)[1]
    look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
    padding_mask = create_padding_mask(x)
    return tf.maximum(look_ahead_mask, padding_mask)

# %% [markdown]
# #### 2) 인코더

# %% [markdown]
# - `단일 인코더`

# %%
# 인코더 하나의 레이어를 함수로 구현.
# 이 하나의 레이어 안에는 두 개의 서브 레이어가 존재합니다.
def encoder_layer(units, d_model, num_heads, dropout, name="encoder_layer"):
    inputs = tf.keras.Input(shape=(None, d_model), name="inputs")

    # 패딩 마스크 사용
    padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

    # 첫 번째 서브 레이어 : 멀티 헤드 어텐션 수행 (셀프 어텐션)
    attention = MultiHeadAttention(
        d_model, num_heads, name="attention")({
            'query': inputs,
            'key': inputs,
            'value': inputs,
            'mask': padding_mask
        })

    # 어텐션의 결과는 Dropout과 Layer Normalization이라는 훈련을 돕는 테크닉을 수행
    attention = tf.keras.layers.Dropout(rate=dropout)(attention)
    attention = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs + attention)

    # 두 번째 서브 레이어 : 2개의 완전연결층
    outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention)
    outputs = tf.keras.layers.Dense(units=d_model)(outputs)

    # 완전연결층의 결과는 Dropout과 LayerNormalization이라는 훈련을 돕는 테크닉을 수행
    outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
    outputs = tf.keras.layers.LayerNormalization(epsilon=1e-6)(attention + outputs)

    return tf.keras.Model(inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %% [markdown]
# - `인코더 여러층 쌓기`

# %%
def encoder(vocab_size,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            name="encoder"):
    inputs = tf.keras.Input(shape=(None,), name="inputs")

    # 패딩 마스크 사용
    padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

    # 임베딩 레이어
    embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
    embeddings *= tf.math.sqrt(tf.cast(d_model, tf.float32))

    # 포지셔널 인코딩
    embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

    outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

    # num_layers만큼 쌓아올린 인코더의 층.
    for i in range(num_layers):
        outputs = encoder_layer(
            units=units,
            d_model=d_model,
            num_heads=num_heads,
            dropout=dropout,
            name="encoder_layer_{}".format(i),
        )([outputs, padding_mask])

    return tf.keras.Model(inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %% [markdown]
# #### 3) 디코더

# %% [markdown]
# - `단일 디코더`

# %%
# 디코더 하나의 레이어를 함수로 구현.
# 이 하나의 레이어 안에는 세 개의 서브 레이어가 존재합니다.
def decoder_layer(units, d_model, num_heads, dropout, name="decoder_layer"):
    inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
    enc_outputs = tf.keras.Input(shape=(None, d_model), name="encoder_outputs")
    look_ahead_mask = tf.keras.Input(shape=(1, None, None), name="look_ahead_mask")
    padding_mask = tf.keras.Input(shape=(1, 1, None), name='padding_mask')

    # 첫 번째 서브 레이어 : 멀티 헤드 어텐션 수행 (셀프 어텐션)
    attention1 = MultiHeadAttention(
    d_model, num_heads, name="attention_1")(inputs={
        'query': inputs,
        'key': inputs,
        'value': inputs,
        'mask': look_ahead_mask
    })

    # 멀티 헤드 어텐션의 결과는 LayerNormalization이라는 훈련을 돕는 테크닉을 수행
    attention1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(attention1 + inputs)

    # 두 번째 서브 레이어 : 마스크드 멀티 헤드 어텐션 수행 (인코더-디코더 어텐션)
    attention2 = MultiHeadAttention(
    d_model, num_heads, name="attention_2")(inputs={
        'query': attention1,
        'key': enc_outputs,
        'value': enc_outputs,
        'mask': padding_mask
    })

    # 마스크드 멀티 헤드 어텐션의 결과는
    # Dropout과 LayerNormalization이라는 훈련을 돕는 테크닉을 수행
    attention2 = tf.keras.layers.Dropout(rate=dropout)(attention2)
    attention2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(attention2 + attention1)

    # 세 번째 서브 레이어 : 2개의 완전연결층
    outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention2)	
    outputs = tf.keras.layers.Dense(units=d_model)(outputs)

    # 완전연결층의 결과는 Dropout과 LayerNormalization 수행
    outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
    outputs = tf.keras.layers.LayerNormalization(epsilon=1e-6)(outputs + attention2)

    return tf.keras.Model(
        inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
        outputs=outputs,
        name=name)

# %% [markdown]
# - `디코더 여러층 쌓기`

# %%
def decoder(vocab_size,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            name='decoder'):
    inputs = tf.keras.Input(shape=(None,), name='inputs')
    enc_outputs = tf.keras.Input(shape=(None, d_model), name='encoder_outputs')
    look_ahead_mask = tf.keras.Input(shape=(1, None, None), name='look_ahead_mask')

    # 패딩 마스크
    padding_mask = tf.keras.Input(shape=(1, 1, None), name='padding_mask')

    # 임베딩 레이어
    embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
    embeddings *= tf.math.sqrt(tf.cast(d_model, tf.float32))

    # 포지셔널 인코딩
    embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

    # Dropout이라는 훈련을 돕는 테크닉을 수행
    outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

    for i in range(num_layers):
        outputs = decoder_layer(
            units=units,
            d_model=d_model,
            num_heads=num_heads,
            dropout=dropout,
            name='decoder_layer_{}'.format(i),
        )(inputs=[outputs, enc_outputs, look_ahead_mask, padding_mask])

    return tf.keras.Model(
        inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
        outputs=outputs,
        name=name)

# %% [markdown]
# #### 4) 트랜스포머 함수 정의

# %%
def transformer(vocab_size,
              num_layers,
              units,
              d_model,
              num_heads,
              dropout,
              name="transformer"):

    inputs = tf.keras.Input(shape=(None,), name="inputs")
    dec_inputs = tf.keras.Input(shape=(None,), name="dec_inputs")

    # 인코더에서 패딩을 위한 마스크
    enc_padding_mask = tf.keras.layers.Lambda(
    create_padding_mask, output_shape=(1, 1, None),
    name='enc_padding_mask')(inputs)

    # 디코더에서 미래의 토큰을 마스크 하기 위해서 사용합니다.
    # 내부적으로 패딩 마스크도 포함되어져 있습니다.
    look_ahead_mask = tf.keras.layers.Lambda(
    create_look_ahead_mask,
    output_shape=(1, None, None),
    name='look_ahead_mask')(dec_inputs)

    # 두 번째 어텐션 블록에서 인코더의 벡터들을 마스킹
    # 디코더에서 패딩을 위한 마스크
    dec_padding_mask = tf.keras.layers.Lambda(
    create_padding_mask, output_shape=(1, 1, None),
    name='dec_padding_mask')(inputs)

    # 인코더
    enc_outputs = encoder(
    vocab_size=vocab_size,
    num_layers=num_layers,
    units=units,
    d_model=d_model,
    num_heads=num_heads,
    dropout=dropout,
    )(inputs=[inputs, enc_padding_mask])

    # 디코더
    dec_outputs = decoder(
    vocab_size=vocab_size,
    num_layers=num_layers,
    units=units,
    d_model=d_model,
    num_heads=num_heads,
    dropout=dropout,
    )(inputs=[dec_inputs, enc_outputs, look_ahead_mask, dec_padding_mask])

    # 완전연결층
    outputs = tf.keras.layers.Dense(units=vocab_size, name="outputs")(dec_outputs)

    return tf.keras.Model(inputs=[inputs, dec_inputs], outputs=outputs, name=name)

# %% [markdown]
# #### 5) 모델 생성

# %% [markdown]
# - 개선 시 layer 층, D_model, DROPOUT 등을 새로이 조정할 수 있을 것이다.

# %%
tf.keras.backend.clear_session()

# 하이퍼파라미터
NUM_LAYERS = 2 # 인코더와 디코더의 층의 개수
D_MODEL = 256 # 인코더와 디코더 내부의 입, 출력의 고정 차원
NUM_HEADS = 8 # 멀티 헤드 어텐션에서의 헤드 수
UNITS = 512 # 피드 포워드 신경망의 은닉층의 크기
DROPOUT = 0.1 # 드롭아웃의 비율

model = transformer(
  vocab_size=VOCAB_SIZE,
  num_layers=NUM_LAYERS,
  units=UNITS,
  d_model=D_MODEL,
  num_heads=NUM_HEADS,
  dropout=DROPOUT)

model.summary()
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, None)]       0
# __________________________________________________________________________________________________
# dec_inputs (InputLayer)         [(None, None)]       0
# __________________________________________________________________________________________________
# enc_padding_mask (Lambda)       (None, 1, 1, None)   0           inputs[0][0]
# __________________________________________________________________________________________________
# encoder (Functional)            (None, None, 256)    3195136     inputs[0][0]
#                                                                  enc_padding_mask[0][0]
# __________________________________________________________________________________________________
# look_ahead_mask (Lambda)        (None, 1, None, None 0           dec_inputs[0][0]
# __________________________________________________________________________________________________
# dec_padding_mask (Lambda)       (None, 1, 1, None)   0           inputs[0][0]
# __________________________________________________________________________________________________
# decoder (Functional)            (None, None, 256)    3722496     dec_inputs[0][0]
#                                                                  encoder[0][0]
#                                                                  look_ahead_mask[0][0]
#                                                                  dec_padding_mask[0][0]
# __________________________________________________________________________________________________
# outputs (Dense)                 (None, None, 8363)   2149291     decoder[0][0]
# ==================================================================================================
# Total params: 9,066,923
# Trainable params: 9,066,923
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### 6) 손실 함수 정의

# %%
def loss_function(y_true, y_pred):
    y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))
    loss = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')(y_true, y_pred)

    mask = tf.cast(tf.not_equal(y_true, 0), tf.float32)
    loss = tf.multiply(loss, mask)

    return tf.reduce_mean(loss)

# %% [markdown]
# #### 7) 커스텀 학습 (콜백함수_LearningRateSchedule)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):

    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps

    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps**-1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %% [markdown]
# - 시각화용 예시(d_model=128, step=200000)

# %%
sample_learning_rate = CustomSchedule(d_model=128)

plt.plot(sample_learning_rate(tf.range(200000, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
# Out:
# Text(0.5, 0, 'Train Step')

# %% [markdown]
# #### 8) 학습 시키기

# %% [markdown]
# - 모델 컴파일

# %%
learning_rate = CustomSchedule(D_MODEL)

optimizer = tf.keras.optimizers.Adam(
    learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

def accuracy(y_true, y_pred):
    y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))
    return tf.keras.metrics.sparse_categorical_accuracy(y_true, y_pred)

model.compile(optimizer=optimizer, loss=loss_function, metrics=[accuracy])

# %% [markdown]
# - 학습

# %%
EPOCHS = 25
model.fit(dataset, epochs=EPOCHS, verbose=1)
# Out:
# Epoch 1/25
# 185/185 [==============================] - 29s 55ms/step - loss: 1.4559 - accuracy: 0.0288
# Epoch 2/25
# 185/185 [==============================] - 10s 54ms/step - loss: 1.1824 - accuracy: 0.0495
# Epoch 3/25
# 185/185 [==============================] - 10s 54ms/step - loss: 1.0065 - accuracy: 0.0507
# Epoch 4/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.9306 - accuracy: 0.0543
# Epoch 5/25
# 185/185 [==============================] - 10s 55ms/step - loss: 0.8727 - accuracy: 0.0575
# Epoch 6/25
# 185/185 [==============================] - 10s 55ms/step - loss: 0.8135 - accuracy: 0.0618
# Epoch 7/25
# 185/185 [==============================] - 10s 55ms/step - loss: 0.7480 - accuracy: 0.0676
# Epoch 8/25
# 185/185 [==============================] - 10s 55ms/step - loss: 0.6754 - accuracy: 0.0752
# Epoch 9/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.5957 - accuracy: 0.0838
# Epoch 10/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.5147 - accuracy: 0.0930
# Epoch 11/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.4320 - accuracy: 0.1032
# Epoch 12/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.3510 - accuracy: 0.1144
# Epoch 13/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.2764 - accuracy: 0.1253
# Epoch 14/25
# 185/185 [==============================] - 10s 55ms/step - loss: 0.2102 - accuracy: 0.1354
# Epoch 15/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.1547 - accuracy: 0.1448
# Epoch 16/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.1121 - accuracy: 0.1527
# Epoch 17/25
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0821 - accuracy: 0.1582
# Epoch 18/25
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0629 - accuracy: 0.1617
# Epoch 19/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0517 - accuracy: 0.1635
# Epoch 20/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0455 - accuracy: 0.1648
# Epoch 21/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0429 - accuracy: 0.1649
# Epoch 22/25
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0410 - accuracy: 0.1652
# Epoch 23/25
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0369 - accuracy: 0.1661
# Epoch 24/25
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0323 - accuracy: 0.1671
# Epoch 25/25
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0280 - accuracy: 0.1683

# %% [markdown]
# - 학습이 끝났는데도 loss함수가 감소세를 보여 학습률을 차차 낮추는 커스텀 콜백 함수를 믿고 100회 정도 epochs를 추가해보았다.

# %%
EPOCHS = 100
history = model.fit(dataset, epochs=EPOCHS, verbose=1)
# Out:
# Epoch 1/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0256 - accuracy: 0.1688
# Epoch 2/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0216 - accuracy: 0.1699
# Epoch 3/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0204 - accuracy: 0.1703
# Epoch 4/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0192 - accuracy: 0.1704
# Epoch 5/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0172 - accuracy: 0.1709
# Epoch 6/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0157 - accuracy: 0.1715
# Epoch 7/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0143 - accuracy: 0.1717
# Epoch 8/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0134 - accuracy: 0.1721
# Epoch 9/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0120 - accuracy: 0.1723
# Epoch 10/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0113 - accuracy: 0.1725
# Epoch 11/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0108 - accuracy: 0.1726
# Epoch 12/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0100 - accuracy: 0.1727
# Epoch 13/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0096 - accuracy: 0.1729
# Epoch 14/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0094 - accuracy: 0.1730
# Epoch 15/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0086 - accuracy: 0.1732
# Epoch 16/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0081 - accuracy: 0.1733
# Epoch 17/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0076 - accuracy: 0.1735
# Epoch 18/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0076 - accuracy: 0.1735
# Epoch 19/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0072 - accuracy: 0.1735
# Epoch 20/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0068 - accuracy: 0.1736
# Epoch 21/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0064 - accuracy: 0.1737
# Epoch 22/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0066 - accuracy: 0.1737
# Epoch 23/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0056 - accuracy: 0.1738
# Epoch 24/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0058 - accuracy: 0.1739
# Epoch 25/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0057 - accuracy: 0.1739
# Epoch 26/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0057 - accuracy: 0.1740
# Epoch 27/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0055 - accuracy: 0.1739
# Epoch 28/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0051 - accuracy: 0.1740
# Epoch 29/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0052 - accuracy: 0.1740
# Epoch 30/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0051 - accuracy: 0.1740
# Epoch 31/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0045 - accuracy: 0.1741
# Epoch 32/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0044 - accuracy: 0.1742
# Epoch 33/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0047 - accuracy: 0.1741
# Epoch 34/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0041 - accuracy: 0.1742
# Epoch 35/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0046 - accuracy: 0.1742
# Epoch 36/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0041 - accuracy: 0.1743
# Epoch 37/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0040 - accuracy: 0.1743
# Epoch 38/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0038 - accuracy: 0.1743
# Epoch 39/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0037 - accuracy: 0.1743
# Epoch 40/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0038 - accuracy: 0.1743
# Epoch 41/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0038 - accuracy: 0.1743
# Epoch 42/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0034 - accuracy: 0.1744
# Epoch 43/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0034 - accuracy: 0.1744
# Epoch 44/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0033 - accuracy: 0.1744
# Epoch 45/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0034 - accuracy: 0.1744
# Epoch 46/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0032 - accuracy: 0.1744
# Epoch 47/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0035 - accuracy: 0.1743
# Epoch 48/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0032 - accuracy: 0.1744
# Epoch 49/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0030 - accuracy: 0.1744
# Epoch 50/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0029 - accuracy: 0.1745
# Epoch 51/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0028 - accuracy: 0.1745
# Epoch 52/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0029 - accuracy: 0.1745
# Epoch 53/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0031 - accuracy: 0.1744
# Epoch 54/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0026 - accuracy: 0.1745
# Epoch 55/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0028 - accuracy: 0.1745
# Epoch 56/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0030 - accuracy: 0.1744
# Epoch 57/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0025 - accuracy: 0.1745
# Epoch 58/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0026 - accuracy: 0.1745
# Epoch 59/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0026 - accuracy: 0.1745
# Epoch 60/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0024 - accuracy: 0.1745
# Epoch 61/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0025 - accuracy: 0.1745
# Epoch 62/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0025 - accuracy: 0.1745
# Epoch 63/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0023 - accuracy: 0.1746
# Epoch 64/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0023 - accuracy: 0.1746
# Epoch 65/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0023 - accuracy: 0.1746
# Epoch 66/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0024 - accuracy: 0.1746
# Epoch 67/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0023 - accuracy: 0.1746
# Epoch 68/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0021 - accuracy: 0.1746
# Epoch 69/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0023 - accuracy: 0.1746
# Epoch 70/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0019 - accuracy: 0.1747
# Epoch 71/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0021 - accuracy: 0.1746
# Epoch 72/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0020 - accuracy: 0.1746
# Epoch 73/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0022 - accuracy: 0.1746
# Epoch 74/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0022 - accuracy: 0.1745
# Epoch 75/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0019 - accuracy: 0.1746
# Epoch 76/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0021 - accuracy: 0.1746
# Epoch 77/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0021 - accuracy: 0.1746
# Epoch 78/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0020 - accuracy: 0.1746
# Epoch 79/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0019 - accuracy: 0.1746
# Epoch 80/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0018 - accuracy: 0.1746
# Epoch 81/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0019 - accuracy: 0.1746
# Epoch 82/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0021 - accuracy: 0.1746
# Epoch 83/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0019 - accuracy: 0.1746
# Epoch 84/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0019 - accuracy: 0.1746
# Epoch 85/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0018 - accuracy: 0.1746
# Epoch 86/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0016 - accuracy: 0.1747
# Epoch 87/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0017 - accuracy: 0.1746
# Epoch 88/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0019 - accuracy: 0.1746
# Epoch 89/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0016 - accuracy: 0.1746
# Epoch 90/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0016 - accuracy: 0.1747
# Epoch 91/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0016 - accuracy: 0.1746
# Epoch 92/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0015 - accuracy: 0.1747
# Epoch 93/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0017 - accuracy: 0.1746
# Epoch 94/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0015 - accuracy: 0.1746
# Epoch 95/100
# 185/185 [==============================] - 10s 55ms/step - loss: 0.0017 - accuracy: 0.1746
# Epoch 96/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0016 - accuracy: 0.1746
# Epoch 97/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0015 - accuracy: 0.1747
# Epoch 98/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0016 - accuracy: 0.1747
# Epoch 99/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0016 - accuracy: 0.1746
# Epoch 100/100
# 185/185 [==============================] - 10s 54ms/step - loss: 0.0015 - accuracy: 0.1747

# %% [markdown]
# ### Step 5. 모델 평가하기

# %%
plt.figure(figsize=(18,5))
plt.title("Loss")
plt.plot(history.history['loss'])
plt.show()

plt.figure(figsize=(18,5))
plt.title("accuracy")
plt.plot(history.history['accuracy'])
plt.show()

# %% [markdown]
# - 100회 추가적으로 돌려보았더니, 40회 이후부터 accuracy든, loss든 큰 개선점을 찾지 못하는 듯하다.
# - 또한 추가적으로 과적합에 대한 걱정으로 현재 데이터와 데이터 내에 없는 문구의 답변을 비교해보고자 한다.

# %%
def decoder_inference(sentence):
    sentence = preprocess_sentence(sentence)

    # 입력된 문장을 정수 인코딩 후, 시작 토큰과 종료 토큰을 앞뒤로 추가.
    # ex) Where have you been? → [[8331   86   30    5 1059    7 8332]]
    sentence = tf.expand_dims(
        START_TOKEN + tokenizer.encode(sentence) + END_TOKEN, axis=0)

    # 디코더의 현재까지의 예측한 출력 시퀀스가 지속적으로 저장되는 변수.
    # 처음에는 예측한 내용이 없음으로 시작 토큰만 별도 저장. ex) 8331
    output_sequence = tf.expand_dims(START_TOKEN, 0)

    # 디코더의 인퍼런스 단계
    for i in range(MAX_LENGTH):
        # 디코더는 최대 MAX_LENGTH의 길이만큼 다음 단어 예측을 반복합니다.
        predictions = model(inputs=[sentence, output_sequence], training=False)
        predictions = predictions[:, -1:, :]

        # 현재 예측한 단어의 정수
        predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

        # 만약 현재 예측한 단어가 종료 토큰이라면 for문을 종료
        if tf.equal(predicted_id, END_TOKEN[0]):
            break

        # 예측한 단어들은 지속적으로 output_sequence에 추가됩니다.
        # 이 output_sequence는 다시 디코더의 입력이 됩니다.
        output_sequence = tf.concat([output_sequence, predicted_id], axis=-1)

    return tf.squeeze(output_sequence, axis=0)

# %%
def sentence_generation(sentence):
    # 입력 문장에 대해서 디코더를 동작 시켜 예측된 정수 시퀀스를 리턴받습니다.
    prediction = decoder_inference(sentence)

    # 정수 시퀀스를 다시 텍스트 시퀀스로 변환합니다.
    predicted_sentence = tokenizer.decode(
        [i for i in prediction if i < tokenizer.vocab_size])

    print('입력 : {}'.format(sentence))
    print('출력 : {}'.format(predicted_sentence))

    return predicted_sentence

# %% [markdown]
# - `후보군 선정`

# %%
ask_list = [df['Q'][17], df['Q'][7], df['Q'][11083], df['Q'][1]]
answer_list = [df['A'][17], df['A'][7], df['A'][11083], df['A'][1]]

# %%
ask_list
# Out:
# ['가스불 켜고 나갔어',
#  'SNS 맞팔 왜 안하지 ㅠ',
#  '좋아하는 사람 생기면 어떻게든 SNS같은 거 알아내서 친신하고 그래 ?',
#  '1지망 학교 떨어졌어']

# %%
answer_list
# Out:
# ['빨리 집에 돌아가서 끄고 나오세요 .',
#  '잘 모르고 있을 수도 있어요 .',
#  '다가가는 방법 중에 하나니까요 .',
#  '위로해 드립니다 .']

# %% [markdown]
# - 1번(일반 문장)
# - 2번(한국어 초성, 중성 사용)
# - 3번(영단어 포함 문장)
# - 4번(숫자 사용)

# %%
for i in range(4) :
    sentence_generation(ask_list[i])
    print(f'실제 : {answer_list[i]}')
    print()
# Out:
# 입력 : 가스불 켜고 나갔어
# 출력 : 빨리 집에 돌아가서 끄고 나오세요 .
# 실제 : 빨리 집에 돌아가서 끄고 나오세요 .
#
# 입력 : SNS 맞팔 왜 안하지 ㅠ
# 출력 : 잘 모르고 있을 수도 있어요 .
# 실제 : 잘 모르고 있을 수도 있어요 .
#
# 입력 : 좋아하는 사람 생기면 어떻게든 SNS같은 거 알아내서 친신하고 그래 ?
# 출력 : 다가가는 방법 중에 하나니까요 .
# 실제 : 다가가는 방법 중에 하나니까요 .
#
# 입력 : 1지망 학교 떨어졌어
# 출력 : 위로해 드립니다 .
# 실제 : 위로해 드립니다 .

# %% [markdown]
# - 묘하게 과한 학습이 진행되지 않았을까라는 생각이 든다.

# %% [markdown]
# - gpt에게 질문을 만들어 달라한 뒤, 해당 질문에 대한 대답을 해달라하여 진행시켜보겠다.
#
# ---
#
# 물론이죠! 아래는 재미있고 다양한 주제의 몇 가지 질문입니다. 😄
#
# - 만약 오늘 하루만 반복해서 살 수 있다면, 어떤 일을 하고 싶나요?
# - 가장 좋아하는 음식은 무엇이고, 그 음식을 왜 좋아하나요?
# - 만약 시간을 되돌릴 수 있다면, 어떤 순간으로 돌아가고 싶나요?
# - 세계 어디든 여행해 볼 수 있다면, 어느 나라로 가고 싶나요?
# - 만약 한 가지 능력을 얻을 수 있다면, 어떤 능력을 가지고 싶나요?

# %%
sentence_generation('만약 오늘 하루만 반복해서 살 수 있다면, 어떤 일을 하고 싶나요?')
# Out:
# 입력 : 만약 오늘 하루만 반복해서 살 수 있다면, 어떤 일을 하고 싶나요?
# 출력 : 잘할 수 있을 거예요 .
# '잘할 수 있을 거예요 .'

# %% [markdown]
# - `gpt : 여러 국가를 여행하며 다양한 문화를 경험하고 싶어요.`

# %%
sentence_generation('가장 좋아하는 음식은 무엇이고, 그 음식을 왜 좋아하나요?')
# Out:
# 입력 : 가장 좋아하는 음식은 무엇이고, 그 음식을 왜 좋아하나요?
# 출력 : 사랑은 재채기 같은 거니까요 .
# '사랑은 재채기 같은 거니까요 .'

# %% [markdown]
# - `gpt : 라면을 정말 좋아해요! 맛도 좋지만 편리하게 끓여 먹을 수 있어서 특히 좋아합니다.`

# %%
sentence_generation('만약 시간을 되돌릴 수 있다면, 어떤 순간으로 돌아가고 싶나요?')
# Out:
# 입력 : 만약 시간을 되돌릴 수 있다면, 어떤 순간으로 돌아가고 싶나요?
# 출력 : 저랑 한 잔 해요 .
# '저랑 한 잔 해요 .'

# %% [markdown]
# - `gpt : 어린 시절 가족과 함께 보낸 특별한 기억이 있는 그 순간으로 돌아가고 싶어요.`

# %%
sentence_generation('세계 어디든 여행해 볼 수 있다면, 어느 나라로 가고 싶나요?')
# Out:
# 입력 : 세계 어디든 여행해 볼 수 있다면, 어느 나라로 가고 싶나요?
# 출력 : 제 생일도 축하해 주세요 .
# '제 생일도 축하해 주세요 .'

# %% [markdown]
# - `gpt : 이탈리아! 아름다운 풍경과 맛있는 음식을 즐기고 싶어요.`

# %%
sentence_generation('마법의 램프를 만났는데 세 가지 소원을 빌 수 있다면, 무엇을 빌고 싶나요?')
# Out:
# 입력 : 마법의 램프를 만났는데 세 가지 소원을 빌 수 있다면, 무엇을 빌고 싶나요?
# 출력 : 조심하세요 .
# '조심하세요 .'

# %% [markdown]
# - `gpt : 1) 모든 언어를 순간적으로 배울 수 있는 능력, 2) 세계 평화, 3) 모든 생명체에게 행복과 번영`

# %%
sentence_generation('만약 한 가지 능력을 얻을 수 있다면, 어떤 능력을 가지고 싶나요?')
# Out:
# 입력 : 만약 한 가지 능력을 얻을 수 있다면, 어떤 능력을 가지고 싶나요?
# 출력 : 약 먹고 쉬어야 해요 .
# '약 먹고 쉬어야 해요 .'

# %% [markdown]
# - `gpt : 모든 생명체의 감정을 이해하고 공감할 수 있는 능력`

# %% [markdown]
# ---

# %% [markdown]
# - 왜 저런 답변을 내었을까? 각 answer와 비슷한 답변이 df['A']이 있는 지 확인해보겠다.

# %%
# 만약 오늘 하루만 반복해서 살 수 있다면, 어떤 일을 하고 싶나요?
df[df['A'] == '잘할 수 있을 거예요 .']
# Out:
#                           Q              A  label
# 1190            대기업 취직 어려울까  잘할 수 있을 거예요 .      0
# 1191           대기업에 취직하고 싶어  잘할 수 있을 거예요 .      0
# 1948          발표 무사히 끝내고 싶어  잘할 수 있을 거예요 .      0
# 1949             발표 잘 하고 싶어  잘할 수 있을 거예요 .      0
# 3822  일에 적응하면 좀 더 잘 할 수 있을까  잘할 수 있을 거예요 .      0
# 4980       학교 잘 적을할 수 있을까 ?  잘할 수 있을 거예요 .      0
# 4981   학교 적을하고 잘 다닐 수 있을까 ?  잘할 수 있을 거예요 .      0
# 5221         회사 적응할 수 있겠지 ?  잘할 수 있을 거예요 .      0
# 5228        회사에 빨리 적응해야 할텐데  잘할 수 있을 거예요 .      0
# 5230         회사에 적응 잘 하고 싶어  잘할 수 있을 거예요 .      0
# 6050    다시 와도 싫다고 단호하게 말해야지  잘할 수 있을 거예요 .      1
# 6512             부디 더 힘내줘 .  잘할 수 있을 거예요 .      1

# %% [markdown]
# - 단순히 많아서 낸 것 같다.

# %%
# 가장 좋아하는 음식은 무엇이고, 그 음식을 왜 좋아하나요?
df[df['A'] == '사랑은 재채기 같은 거니까요 .']
# Out:
#                        Q                  A  label
# 5776  나도 모르게 니 생각을 하고 있어  사랑은 재채기 같은 거니까요 .      1

# %% [markdown]
# - 단어 임베딩의 위치가 비슷해서 나온건가??
#     - 몇몇 단어의 번호가 생각보다 근처이다.

# %%
print(f'생각 : {vocab.index("생각")}')
print(f'음식 : {vocab.index("음식")}')
print(f'사랑 : {vocab.index("사랑")}')
print(f'가장 : {vocab.index("가장")}')
# Out:
# 생각 : 355
# 음식 : 4066
# 사랑 : 212
# 가장 : 398

# %% [markdown]
# - 재채기란 문구는 이상하게 없다.

# %%
print(f'재채기 : {vocab.index("재채기")}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_31/103730739.py in <module>
# ----> 1 print(f'재채기 : {vocab.index("재채기")}')
#
# ValueError: '재채기' is not in list

# %%
# 만약 시간을 되돌릴 수 있다면, 어떤 순간으로 돌아가고 싶나요?
df[df['A'] == '저랑 한 잔 해요 .']
# Out:
#                 Q            A  label
# 1574  맥주 한 잔 어때 ?  저랑 한 잔 해요 .      0
# 1575  맥주 한 잔 할래 ?  저랑 한 잔 해요 .      0
# 2616     술 마시고 싶다  저랑 한 잔 해요 .      0
# 5008    한 잔 하고 싶다  저랑 한 잔 해요 .      0

# %%
# 세계 어디든 여행해 볼 수 있다면, 어느 나라로 가고 싶나요?
df[df['A'] == '제 생일도 축하해 주세요 .']
# Out:
#                Q                A  label
# 6679  생일축하했다 바보야  제 생일도 축하해 주세요 .      1

# %%
# 마법의 램프를 만났는데 세 가지 소원을 빌 수 있다면, 무엇을 빌고 싶나요?
df[df['A'] == '조심하세요 .']
# Out:
#                         Q        A  label
# 409      길이 미끄러워서 미끄러질뻔했어  조심하세요 .      0
# 411        길이 얼어서 미끄러질뻔했어  조심하세요 .      0
# 989                넘어질뻔했어  조심하세요 .      0
# 1699          모기가 너무 많아 .  조심하세요 .      0
# 1700           모기가 웽웽거려 .  조심하세요 .      0
# 1761            무서워서 달려왔어  조심하세요 .      0
# 1762           무서워서 뛰어 왔어  조심하세요 .      0
# 2171                불 날 뻔  조심하세요 .      0
# 2172              불 날 뻔했어  조심하세요 .      0
# 2243          빨리 걷다가 넘어질뻔  조심하세요 .      0
# 3820  일어나보니까 침대에서 떨어져 있었어  조심하세요 .      0
# 3924        자다가 침대에서 떨어졌어  조심하세요 .      0
# 4891                폰 떨궜어  조심하세요 .      0
# 5062           핸드폰 떨어 뜨렸어  조심하세요 .      0

# %%
# 만약 한 가지 능력을 얻을 수 있다면, 어떤 능력을 가지고 싶나요?
df[df['A'] == '약 먹고 쉬어야 해요 .']
# Out:
#                    Q              A  label
# 3007  약 기운에 졸음이 몰려왔어  약 먹고 쉬어야 해요 .      0
# 3009       약 먹었더니 졸려  약 먹고 쉬어야 해요 .      0

# %% [markdown]
# ---

# %% [markdown]
# - 취약점을 찾고자 generate와 실제 데이터를 비교해보고자 한다.

# %%
def sentence_generation2(sentence):
    # 입력 문장에 대해서 디코더를 동작 시켜 예측된 정수 시퀀스를 리턴받습니다.
    prediction = decoder_inference(sentence)

    # 정수 시퀀스를 다시 텍스트 시퀀스로 변환합니다.
    predicted_sentence = tokenizer.decode(
        [i for i in prediction if i < tokenizer.vocab_size])
    return predicted_sentence

# %%
gen_data = df.copy()
gen_data["G"] = gen_data['Q'].apply(lambda x:sentence_generation2(x))
differ = gen_data[gen_data['A'] != gen_data['G']]

# %%
differ.head(20)
# Out:
#                  Q                        A  label  \
# 195     고양이 키우고 싶어            자신을 먼저 키우세요 .      0
# 234      공시 준비 힘들어                합격 기원해요 !      0
# 980         너무 힘들다             휴가가 간절하겠네요 .      0
# 1243          더워더워  차가운 음료 너무 많이 마시면 아니 되어요      0
# 1294       돈 벌고 싶어             많이 벌수록 좋아요 .      0
# 1445     로또 번호 알려줘               알면 제가 하죠 .      0
# 1481       마음이 울적해              거리를 걸어보세요 .      0
# 1500    만나기만 하면 싸워             성격이 안 맞나봐요 .      0
# 1536       말이 안 통해    대화의 눈높이가 맞는 사람 만나세요 .      0
# 1834  뭐하면 시간이 잘 갈까            친구와 수다를 떠세요 .      0
# 1898       바라는게 없어            살고 싶은대로 사세요 .      0
# 1914           반가워                  반갑습니다 .      0
# 1945       발목 접질렀어                병원 가보세요 .      0
# 2000           배고파           얼른 맛난 음식 드세요 .      0
# 2013           배불러             산책 좀 해야겠네여 .      0
# 2198       비 오는데 ?             우산 들고 나가세요 .      0
# 2456    선풍기 틀어도 더워         시원한 아이스크림 어떠세요 ?      0
# 2535       속이 안 좋아            소화가 안 되나 봐요 .      0
# 2584    수업시간 내내 잤어            한창 잠이 많을 때죠 .      0
# 2617      술 마시고 싶다                 같이 마셔요 .      0
#
#                                         G
# 195                         가족들과 상의해보세요 .
# 234                             잘 될 거예요 .
# 980   지금 무슨 말을 해도 와닿지 않겠지만 잘 이겨낼 거라 믿어요 .
# 1243                              여름이네요 .
# 1294                                저도요 .
# 1445                 제가 알면 제가 먼저 했을 거예요 .
# 1481                     소리를 크게한번 질러보세요 .
# 1500                            만나지 마세요 .
# 1536                            포기하지마세요 .
# 1834                                멍 때리기
# 1898             살다보면 하고 싶은 게 생길 수도 있어요 .
# 1914                            저도 반가워요 .
# 1945                          꾸준히 치료하세요 .
# 2000                          뭐 좀 챙겨드세요 .
# 2013                              좀 쉬세요 .
# 2198                            우산 챙기세요 .
# 2456                   카페라도 가서 쉬다 오면 어떨까요
# 2535                       신경 쓸 일이 있나봐요 .
# 2584                             피곤한가봐요 .
# 2617                          저랑 한 잔 해요 .

# %% [markdown]
# - 다른 것을 다 뽑아보았는데 생각외로 조금 더 나은 답변을 보여주는 듯 하다.

# %%
differ.count()
# Out:
# Q        101
# A        101
# label    101
# G        101
# dtype: int64

# %% [markdown]
# ### 회고
# #### Keep
# - 이것저것 가능한한 과정을 이해해보려 노력해본 것 같다. 더불어 다양한 시도를 하며 모든 결정을 근거있게 해보려 노력하였다.
#
# #### Problem
# - 문제는 단순히 에폭을 늘리는 것만으로 모델의 성능이 오르는 것 같지 않다. 데이터 불균형의 문제점을 파악하고도 따로 데이터 증강을 시도하지 않았다.
#
# #### Try
# - gpt, 실제 정답 데이터와 예측 데이터를 직접 눈으로 비교해보려 노력하였다.
